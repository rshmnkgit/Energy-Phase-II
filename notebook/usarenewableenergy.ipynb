# %%
#import dependencies

# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
from pprint import pprint
from pymongo import MongoClient

# %%
data_path="../Resources/"

# %%
# pop_df = pd.read_csv(data_path+"nst-est2019-popchg2010_2019.csv",skiprows =range(1,6))

# %%
# pop_df

# %%
# pop_df=pop_df.iloc[:,4:16]

# %%
# pop_df.head()

# %%
# pop_df.columns

# %%
# #rename the columns
# pop_df = pop_df.rename(columns={"NAME":"State","ESTIMATESBASE2010":"EST2010","POPESTIMATE2010":"2010", 
#                                 'POPESTIMATE2011': '2011', 'POPESTIMATE2012': '2012',
#                                'POPESTIMATE2013' : '2013', 'POPESTIMATE2014': '2014', 
#                                 'POPESTIMATE2015' : '2015', 'POPESTIMATE2016' :'2016', 
#                                 'POPESTIMATE2017' :'2017', 'POPESTIMATE2018': '2018','POPESTIMATE2019': '2019'})

# %%
# # convert the data change columns to rows so our data is linear
# pop_df = pop_df.melt(id_vars =["State"], var_name ="Year",value_name = "Population")
# pop_df

# %%
# us_pop = pop_df.groupby(['Year']).sum().reset_index()
# us_pop

# %%
# #slicing the data in the desired format
# pop_df1=pop_df.iloc[:,4:16]
# #df1 = df.iloc[:, 0:2]

# %%
# pop_df1.head()

# %%
energy_cons = pd.read_excel(data_path+"Table_1.3_Primary_Energy_Consumption_by_Source.xlsx",'Annual Data',skiprows=range(0,10))

# %%
energy_cons
# Out:
#     Annual Total   Coal Consumption  \
# 0            NaN  (Quadrillion Btu)
# 1         1949.0            11.9809
# 2         1950.0            12.3471
# 3         1951.0             12.553
# 4         1952.0            11.3065
# ..           ...                ...
# 67        2015.0            15.5489
# 68        2016.0            14.2259
# 69        2017.0            13.8375
# 70        2018.0            13.2515
# 71        2019.0            11.3155
#
#    Natural Gas Consumption (Excluding Supplemental Gaseous Fuels)  \
# 0                                   (Quadrillion Btu)
# 1                                             5.14514
# 2                                             5.96837
# 3                                             7.04852
# 4                                             7.54962
# ..                                                ...
# 67                                            28.1911
# 68                                            28.4004
# 69                                            28.0551
# 70                                            31.1534
# 71                                            32.1958
#
#    Petroleum Consumption (Excluding Biofuels) Total Fossil Fuels Consumption  \
# 0                           (Quadrillion Btu)              (Quadrillion Btu)
# 1                                      11.869                        28.9884
# 2                                     13.2983                        31.6148
# 3                                     14.4077                        33.9877
# 4                                     14.9339                        33.7781
# ..                                        ...                            ...
# 67                                    35.3681                        79.0903
# 68                                    35.7119                         78.319
# 69                                    36.0432                        77.9071
# 70                                    36.8918                        81.2711
# 71                                    36.8664                        80.3566
#
#    Nuclear Electric Power Consumption Hydroelectric Power Consumption  \
# 0                   (Quadrillion Btu)               (Quadrillion Btu)
# 1                                   0                         1.42472
# 2                                   0                         1.41541
# 3                                   0                         1.42379
# 4                                   0                         1.46581
# ..                                ...                             ...
# 67                            8.33689                         2.32118
# 68                            8.42675                         2.47244
# 69                            8.41897                         2.76697
# 70                            8.43807                         2.66314
# 71                            8.45185                         2.56323
#
#    Geothermal Energy Consumption Solar Energy Consumption  \
# 0              (Quadrillion Btu)        (Quadrillion Btu)
# 1                  Not Available            Not Available
# 2                  Not Available            Not Available
# 3                  Not Available            Not Available
# 4                  Not Available            Not Available
# ..                           ...                      ...
# 67                      0.211836                 0.426867
# 68                      0.209604                 0.570368
# 69                      0.210233                 0.777084
# 70                      0.208865                 0.915513
# 71                      0.201269                  1.01801
#
#    Wind Energy Consumption Biomass Energy Consumption  \
# 0        (Quadrillion Btu)          (Quadrillion Btu)
# 1            Not Available                    1.54926
# 2            Not Available                    1.56231
# 3            Not Available                    1.53467
# 4            Not Available                    1.47437
# ..                     ...                        ...
# 67                 1.77731                    4.98336
# 68                 2.09559                    5.01452
# 69                 2.34289                    4.97934
# 70                 2.48236                     5.0311
# 71                 2.62585                    4.92381
#
#    Total Renewable Energy Consumption Total Primary Energy Consumption
# 0                   (Quadrillion Btu)                (Quadrillion Btu)
# 1                             2.97398                          31.9678
# 2                             2.97772                          34.5986
# 3                             2.95846                          36.9537
# 4                             2.94018                           36.726
# ..                                ...                              ...
# 67                            9.72054                          97.3752
# 68                            10.3625                          97.3352
# 69                            11.0765                          97.5947
# 70                             11.301                          101.162
# 71                            11.3322                          100.274
#
# [72 rows x 13 columns]

# %%
energy_cons = energy_cons.rename(columns={'Annual Total':'Year', 'Coal Consumption':'Coal_Consumption',
       'Natural Gas Consumption (Excluding Supplemental Gaseous Fuels)':'Gas_Consumption',
       'Petroleum Consumption (Excluding Biofuels)':"Petro_Consumption",
       'Total Fossil Fuels Consumption':'Fossil_Consumption', 'Nuclear Electric Power Consumption':'Electric_consumption',
       'Hydroelectric Power Consumption':'Hydro_Consumption', 'Geothermal Energy Consumption':'Geo_Consumption',
       'Solar Energy Consumption':'Solar_Consumption', 'Wind Energy Consumption':'Wind_Consumption',
       'Biomass Energy Consumption':'Bio_Consumption', 'Total Renewable Energy Consumption':'Total_Renewable_Consumption',
       'Total Primary Energy Consumption':'Total_primary_Cosumption'})

# %%
# dropping column with all null values 
energy_cons.dropna(axis =1 ,how = "all", inplace = True)

# %%
energy_cons.drop(index=0, inplace=True)

# %%
energy_cons.head(60)
# Out:
#       Year Coal_Consumption Gas_Consumption Petro_Consumption  \
# 1   1949.0          11.9809         5.14514            11.869
# 2   1950.0          12.3471         5.96837           13.2983
# 3   1951.0           12.553         7.04852           14.4077
# 4   1952.0          11.3065         7.54962           14.9339
# 5   1953.0          11.3727         7.90665            15.532
# 6   1954.0          9.71467          8.3302           15.8133
# 7   1955.0          11.1673         8.99794           17.2253
# 8   1956.0          11.3497         9.61397            17.905
# 9   1957.0          10.8206         10.1908           17.8984
# 10  1958.0          9.53329         10.6632           18.4912
# 11  1959.0          9.51835         11.7174           19.2799
# 12  1960.0          9.83779         12.3854           19.8735
# 13  1961.0          9.62335         12.9264           20.1693
# 14  1962.0          9.90645         13.7308           20.9976
# 15  1963.0          10.4125         14.4033           21.6453
# 16  1964.0          10.9644         15.2879           22.2419
# 17  1965.0          11.5806         15.7687           23.1839
# 18  1966.0          12.1431         16.9953           24.3354
# 19  1967.0          11.9138         17.9448            25.274
# 20  1968.0          12.3307         19.2097           26.9664
# 21  1969.0          12.3815          20.678           28.3206
# 22  1970.0          12.2645         21.7947           29.4992
# 23  1971.0          11.5984         22.4691           30.5387
# 24  1972.0          12.0769         22.6982           32.9189
# 25  1973.0          12.9715         22.5124            34.806
# 26  1974.0          12.6629         21.7325           33.4206
# 27  1975.0          12.6628         19.9479           32.6988
# 28  1976.0          13.5841         20.3454            35.142
# 29  1977.0          13.9221         19.9305           37.0826
# 30  1978.0          13.7656         20.0004           37.9191
# 31  1979.0          15.0396         20.6658           37.0755
# 32  1980.0          15.4228         20.2355            34.159
# 33  1981.0          15.9075         19.7473           31.8836
# 34  1982.0          15.3216         18.3562           30.1792
# 35  1983.0          15.8944         17.2208            29.997
# 36  1984.0          17.0706         18.3936           30.9922
# 37  1985.0          17.4784         17.7035           30.8665
# 38  1986.0          17.2604         16.5914           32.1501
# 39  1987.0          18.0085         17.6398           32.8175
# 40  1988.0          18.8463         18.4484           34.1728
# 41  1989.0          19.0698         19.6016            34.164
# 42  1990.0          19.1726         19.6033           33.4999
# 43  1991.0          18.9917          20.033           32.7891
# 44  1992.0          19.1225         20.7136           33.4677
# 45  1993.0          19.8351          21.229           33.5876
# 46  1994.0          19.9095         21.7281           34.4534
# 47  1995.0          20.0887         22.6711           34.3411
# 48  1996.0          21.0019         23.0846           35.5889
# 49  1997.0          21.4454         23.2227           36.0651
# 50  1998.0          21.6557         22.8302           36.7198
# 51  1999.0          21.6225         22.9092           37.7321
# 52  2000.0          22.5795          23.824           38.1516
# 53  2001.0          21.9143         22.7726           38.0837
# 54  2002.0           21.904         23.5101           38.1174
# 55  2003.0          22.3209         22.8306            38.707
# 56  2004.0          22.4662         22.9231           40.1393
# 57  2005.0          22.7965         22.5654           40.2166
# 58  2006.0          22.4472         22.2387           39.7305
# 59  2007.0          22.7495         23.6628           39.3676
# 60  2008.0          22.3874          23.843           36.7694
#
#    Fossil_Consumption Electric_consumption Hydro_Consumption Geo_Consumption  \
# 1             28.9884                    0           1.42472   Not Available
# 2             31.6148                    0           1.41541   Not Available
# 3             33.9877                    0           1.42379   Not Available
# 4             33.7781                    0           1.46581   Not Available
# 5             34.8023                    0           1.41286   Not Available
# 6             33.8515                    0           1.35977   Not Available
# 7             37.3804                    0           1.35984   Not Available
# 8             38.8557                    0           1.43471   Not Available
# 9             38.8923             0.000112           1.51561   Not Available
# 10             38.681             0.001915           1.59197   Not Available
# 11            40.5073             0.002187           1.54846   Not Available
# 12             42.091             0.006026           1.60797        0.000359
# 13            42.7112             0.019678           1.65646        0.001001
# 14            44.6294             0.026394           1.81614        0.001061
# 15            46.4537             0.038147           1.77136         0.00176
# 16            48.4837             0.039819           1.88631        0.002132
# 17            50.5147             0.043164           2.05908        0.001978
# 18            53.4488             0.064158           2.06152        0.001958
# 19            55.1172             0.088456           2.34666          0.0033
# 20            58.4894             0.141534           2.34863        0.004532
# 21             61.344             0.153722           2.64798        0.006422
# 22            63.5008             0.239347           2.63355        0.005511
# 23            64.5731             0.412939           2.82415        0.005739
# 24             67.668             0.583752           2.86387        0.015079
# 25            70.2824             0.910177           2.86145        0.020422
# 26            67.8721              1.27208           3.17658         0.02561
# 27             65.323               1.8998           3.15461         0.03378
# 28            69.0714              2.11112           2.97627        0.037513
# 29            70.9498              2.70176           2.33325        0.037382
# 30            71.8098              3.02413           2.93698        0.030851
# 31            72.8437              2.77583           2.93069        0.040262
# 32            69.7822              2.73917           2.90014        0.052699
# 33            67.5225              3.00759           2.75797        0.059437
# 34            63.8354              3.13115           3.26556        0.050627
# 35            63.0967              3.20255           3.52726         0.06391
# 36             66.445              3.55253           3.38581        0.080811
# 37            66.0349              4.07556           2.97019        0.097421
# 38            65.9852              4.38011           3.07118        0.107677
# 39            68.4744              4.75393           2.63451         0.11227
# 40             71.507              5.58697           2.33426        0.106338
# 41            72.8657              5.60216           2.83726        0.161539
# 42            72.2806              6.10435           3.04639        0.170747
# 43            71.8234              6.42213           3.01594        0.177626
# 44            73.3384              6.47921           2.61744        0.178699
# 45            74.6788               6.4105           2.89161        0.185673
# 46            76.1493              6.69388           2.68346        0.173464
# 47             77.162              7.07544           3.20531        0.152057
# 48            79.6983              7.08667           3.58966        0.163359
# 49            80.7797              6.59699           3.64046        0.166698
# 50            81.2729              7.06781           3.29705         0.16845
# 51            82.3216              7.61026           3.26757        0.170921
# 52            84.6204              7.86235           2.81112        0.164364
# 53            82.7998              8.02885           2.24186        0.164461
# 54            83.5923              8.14543           2.68902        0.171164
# 55            83.9091              7.95962           2.79254        0.173445
# 56            85.6663              8.22277           2.68847        0.178147
# 57            85.6227              8.16081           2.70294        0.180703
# 58            84.4772              8.21463           2.86903          0.1812
# 59             85.805              8.45859           2.44639        0.185774
# 60            83.0405              8.42649           2.51111        0.192433
#
#    Solar_Consumption Wind_Consumption Bio_Consumption  \
# 1      Not Available    Not Available         1.54926
# 2      Not Available    Not Available         1.56231
# 3      Not Available    Not Available         1.53467
# 4      Not Available    Not Available         1.47437
# 5      Not Available    Not Available          1.4186
# 6      Not Available    Not Available         1.39433
# 7      Not Available    Not Available         1.42414
# 8      Not Available    Not Available         1.41587
# 9      Not Available    Not Available         1.33358
# 10     Not Available    Not Available         1.32312
# 11     Not Available    Not Available         1.35287
# 12     Not Available    Not Available         1.31987
# 13     Not Available    Not Available         1.29476
# 14     Not Available    Not Available         1.30024
# 15     Not Available    Not Available         1.32332
# 16     Not Available    Not Available          1.3368
# 17     Not Available    Not Available         1.33476
# 18     Not Available    Not Available         1.36898
# 19     Not Available    Not Available         1.34025
# 20     Not Available    Not Available         1.41949
# 21     Not Available    Not Available         1.44049
# 22     Not Available    Not Available         1.43096
# 23     Not Available    Not Available         1.43232
# 24     Not Available    Not Available         1.50307
# 25     Not Available    Not Available         1.52907
# 26     Not Available    Not Available         1.53966
# 27     Not Available    Not Available         1.49873
# 28     Not Available    Not Available         1.71337
# 29     Not Available    Not Available         1.83833
# 30     Not Available    Not Available         2.03761
# 31     Not Available    Not Available         2.15191
# 32     Not Available    Not Available          2.4755
# 33     Not Available    Not Available         2.59628
# 34     Not Available    Not Available         2.66345
# 35     Not Available          2.8e-05         2.90441
# 36           5.5e-05          6.8e-05         2.97112
# 37          0.000111            6e-05         3.01623
# 38          0.000147          4.4e-05         2.93209
# 39          0.000109          3.7e-05         2.87488
# 40           9.4e-05            9e-06         3.01605
# 41          0.054466         0.022033         3.15936
# 42          0.058768         0.029007         2.73511
# 43          0.061623         0.030796          2.7818
# 44           0.06288         0.029863         2.93168
# 45           0.06519         0.030987         2.90817
# 46          0.067126          0.03556         3.02753
# 47          0.068233          0.03263         3.10114
# 48          0.069134          0.03344         3.15681
# 49          0.068166         0.033581         3.10522
# 50          0.067449         0.030853         2.92749
# 51          0.066066         0.045894         2.96329
# 52          0.063469         0.057057         3.00823
# 53          0.061674         0.069617         2.62236
# 54           0.05998         0.105334         2.70062
# 55          0.058432         0.113273         2.80647
# 56          0.058376         0.141664         3.00807
# 57          0.057893         0.178088         3.11393
# 58          0.060755         0.263738         3.26214
# 59          0.065621         0.340503         3.48482
# 60          0.074207         0.545548         3.85139
#
#    Total_Renewable_Consumption Total_primary_Cosumption
# 1                      2.97398                  31.9678
# 2                      2.97772                  34.5986
# 3                      2.95846                  36.9537
# 4                      2.94018                   36.726
# 5                      2.83146                  37.6406
# 6                       2.7541                  36.6135
# 7                      2.78399                  40.1783
# 8                      2.85058                  41.7218
# 9                      2.84919                  41.7539
# 10                     2.91509                  41.6093
# 11                     2.90134                   43.423
# 12                      2.9282                  45.0407
# 13                     2.95223                  45.6908
# 14                     3.11744                   47.775
# 15                     3.09643                  49.5886
# 16                     3.22525                  51.7554
# 17                     3.39582                  53.9532
# 18                     3.43246                  56.9492
# 19                     3.69021                  58.8948
# 20                     3.77266                  62.4015
# 21                     4.09489                  65.5963
# 22                     4.07002                  67.8168
# 23                     4.26221                  69.2603
# 24                     4.38201                    72.66
# 25                     4.41094                  75.6523
# 26                     4.74185                  73.9293
# 27                     4.68712                   71.931
# 28                     4.72715                   75.939
# 29                     4.20897                    77.92
# 30                     5.00544                  79.9067
# 31                     5.12285                  80.8118
# 32                     5.42834                  78.0211
# 33                     5.41369                  76.0572
# 34                     5.97964                  73.0462
# 35                     6.49561                  72.9154
# 36                     6.43786                  76.5707
# 37                     6.08402                  76.3341
# 38                     6.11114                  76.5989
# 39                     5.62181                  79.0082
# 40                     5.45675                  82.6592
# 41                     6.23466                    84.74
# 42                     6.04002                  84.4329
# 43                     6.06778                  84.3803
# 44                     5.82056                  85.7249
# 45                     6.08164                  87.2659
# 46                     5.98714                  88.9832
# 47                     6.55937                  90.9307
# 48                     7.01239                  93.9345
# 49                     7.01412                   94.507
# 50                      6.4913                  94.9202
# 51                     6.51375                  96.5445
# 52                     6.10423                  98.7022
# 53                     5.15997                  96.0637
# 54                     5.72612                  97.5354
# 55                     5.94416                  97.8348
# 56                     6.07473                  100.002
# 57                     6.23356                  100.102
# 58                     6.63687                  99.3915
# 59                     6.52311                  100.893
# 60                     7.17469                  98.7537

# %%
energy_cons['Year'] = energy_cons['Year'].astype(int)

# %%
energy_cons.head()
# Out:
#    Year Coal_Consumption Gas_Consumption Petro_Consumption Fossil_Consumption  \
# 1  1949          11.9809         5.14514            11.869            28.9884
# 2  1950          12.3471         5.96837           13.2983            31.6148
# 3  1951           12.553         7.04852           14.4077            33.9877
# 4  1952          11.3065         7.54962           14.9339            33.7781
# 5  1953          11.3727         7.90665            15.532            34.8023
#
#   Electric_consumption Hydro_Consumption Geo_Consumption Solar_Consumption  \
# 1                    0           1.42472   Not Available     Not Available
# 2                    0           1.41541   Not Available     Not Available
# 3                    0           1.42379   Not Available     Not Available
# 4                    0           1.46581   Not Available     Not Available
# 5                    0           1.41286   Not Available     Not Available
#
#   Wind_Consumption Bio_Consumption Total_Renewable_Consumption  \
# 1    Not Available         1.54926                     2.97398
# 2    Not Available         1.56231                     2.97772
# 3    Not Available         1.53467                     2.95846
# 4    Not Available         1.47437                     2.94018
# 5    Not Available          1.4186                     2.83146
#
#   Total_primary_Cosumption
# 1                  31.9678
# 2                  34.5986
# 3                  36.9537
# 4                   36.726
# 5                  37.6406

# %%
#df = df.apply(lambda x: pd.to_numeric(x, errors='coerce')).fillna(-999999)
#energy_cons1 = energy_cons.apply(lambda x: pd.to_numeric(x, errors='coerce')).fillna(-999999)
#energy_cons1=energy_cons.replace("^\w.*$", "0", regex=True)
#Replace Not available with zeros
energy_cons = energy_cons.replace('Not Available',0)

# %%
energy_cons.head()
# Out:
#    Year  Coal_Consumption  Gas_Consumption  Petro_Consumption  \
# 1  1949         11.980905         5.145142          11.868994
# 2  1950         12.347109         5.968371          13.298283
# 3  1951         12.552996         7.048518          14.407674
# 4  1952         11.306479         7.549621          14.933895
# 5  1953         11.372684         7.906645          15.531959
#
#    Fossil_Consumption  Electric_consumption  Hydro_Consumption  \
# 1           28.988371                   0.0           1.424722
# 2           31.614755                   0.0           1.415411
# 3           33.987736                   0.0           1.423795
# 4           33.778116                   0.0           1.465812
# 5           34.802286                   0.0           1.412859
#
#    Geo_Consumption  Solar_Consumption  Wind_Consumption  Bio_Consumption  \
# 1              0.0                0.0               0.0         1.549262
# 2              0.0                0.0               0.0         1.562307
# 3              0.0                0.0               0.0         1.534669
# 4              0.0                0.0               0.0         1.474369
# 5              0.0                0.0               0.0         1.418601
#
#    Total_Renewable_Consumption  Total_primary_Cosumption
# 1                     2.973984                 31.967775
# 2                     2.977718                 34.598567
# 3                     2.958464                 36.953661
# 4                     2.940181                 36.726037
# 5                     2.831460                 37.640598

# %% [markdown]
# # Energy Production

# %%
energy_prod = pd.read_excel(data_path+"Table_10.1_Renewable_Energy_Production_and_Consumption_by_Source.xlsx",'Annual Data',skiprows=range(0,10))

# %%
energy_prod
# Out:
#     Annual Total Wood Energy Production Biofuels Production  \
# 0            NaN         (Trillion Btu)      (Trillion Btu)
# 1         1949.0                1549.26       Not Available
# 2         1950.0                1562.31       Not Available
# 3         1951.0                1534.67       Not Available
# 4         1952.0                1474.37       Not Available
# ..           ...                    ...                 ...
# 67        2015.0                2311.77             2161.44
# 68        2016.0                 2296.7             2274.95
# 69        2017.0                2259.19              2344.3
# 70        2018.0                2354.56             2396.57
# 71        2019.0                2330.28             2327.52
#
#    Total Biomass Energy Production Total Renewable Energy Production  \
# 0                   (Trillion Btu)                    (Trillion Btu)
# 1                          1549.26                           2973.98
# 2                          1562.31                           2977.72
# 3                          1534.67                           2958.46
# 4                          1474.37                           2940.18
# ..                             ...                               ...
# 67                         4991.58                           9728.76
# 68                         5074.86                           10422.9
# 69                         5098.75                           11195.9
# 70                         5238.48                           11508.4
# 71                         5100.24                           11508.6
#
#    Hydroelectric Power Consumption Geothermal Energy Consumption  \
# 0                   (Trillion Btu)                (Trillion Btu)
# 1                          1424.72                 Not Available
# 2                          1415.41                 Not Available
# 3                           1423.8                 Not Available
# 4                          1465.81                 Not Available
# ..                             ...                           ...
# 67                         2321.18                       211.836
# 68                         2472.44                       209.604
# 69                         2766.97                       210.233
# 70                         2663.14                       208.865
# 71                         2563.23                       201.269
#
#    Solar Energy Consumption Wind Energy Consumption Wood Energy Consumption  \
# 0            (Trillion Btu)          (Trillion Btu)          (Trillion Btu)
# 1             Not Available           Not Available                 1549.26
# 2             Not Available           Not Available                 1562.31
# 3             Not Available           Not Available                 1534.67
# 4             Not Available           Not Available                 1474.37
# ..                      ...                     ...                     ...
# 67                  426.867                 1777.31                 2311.77
# 68                  570.368                 2095.59                 2224.12
# 69                  777.084                 2342.89                 2180.56
# 70                  915.513                 2482.36                 2260.51
# 71                  1018.01                 2625.85                 2226.64
#
#    Waste Energy Consumption Biofuels Consumption  \
# 0            (Trillion Btu)       (Trillion Btu)
# 1             Not Available        Not Available
# 2             Not Available        Not Available
# 3             Not Available        Not Available
# 4             Not Available        Not Available
# ..                      ...                  ...
# 67                  518.371              2153.22
# 68                  503.219              2287.18
# 69                   495.26              2303.52
# 70                  487.347              2283.25
# 71                  442.447              2254.72
#
#    Total Biomass Energy Consumption Total Renewable Energy Consumption
# 0                    (Trillion Btu)                     (Trillion Btu)
# 1                           1549.26                            2973.98
# 2                           1562.31                            2977.72
# 3                           1534.67                            2958.46
# 4                           1474.37                            2940.18
# ..                              ...                                ...
# 67                          4983.36                            9720.54
# 68                          5014.52                            10362.5
# 69                          4979.34                            11076.5
# 70                           5031.1                              11301
# 71                          4923.81                            11332.2
#
# [72 rows x 14 columns]

# %%
energy_prod = energy_prod.rename(columns={'Annual Total':'Year', 'Wood Energy Production':'Wood_production', 'Biofuels Production':'Biofuel_Production',
       'Total Biomass Energy Production':'Total_Biomass_Prod', 'Total Renewable Energy Production':'Total_Renewable_Production',
       'Hydroelectric Power Consumption':'Hydro_consumption', 'Geothermal Energy Consumption':'Geo_Consumption',
       'Solar Energy Consumption':'Solar_Consumption', 'Wind Energy Consumption':'Wind_Consumption',
       'Wood Energy Consumption':'Wood_Consumption', 'Waste Energy Consumption':'WasteEnergy_Consumption',
       'Biofuels Consumption':'Biofuel_consumption', 'Total Biomass Energy Consumption':'Total_Biomass_Consumption',
       'Total Renewable Energy Consumption':'Total_Renewable_Consumption'})

# %%
# dropping column with all null values
energy_prod.dropna(axis =1 ,how = "all",inplace = True)

# %%
energy_prod.drop(index=0, inplace=True)

# %%
energy_prod.head()
# Out:
#      Year Wood_production Biofuel_Production Total_Biomass_Prod  \
# 1  1949.0         1549.26      Not Available            1549.26
# 2  1950.0         1562.31      Not Available            1562.31
# 3  1951.0         1534.67      Not Available            1534.67
# 4  1952.0         1474.37      Not Available            1474.37
# 5  1953.0          1418.6      Not Available             1418.6
#
#   Total_Renewable_Production Hydro_consumption Geo_Consumption  \
# 1                    2973.98           1424.72   Not Available
# 2                    2977.72           1415.41   Not Available
# 3                    2958.46            1423.8   Not Available
# 4                    2940.18           1465.81   Not Available
# 5                    2831.46           1412.86   Not Available
#
#   Solar_Consumption Wind_Consumption Wood_Consumption WasteEnergy_Consumption  \
# 1     Not Available    Not Available          1549.26           Not Available
# 2     Not Available    Not Available          1562.31           Not Available
# 3     Not Available    Not Available          1534.67           Not Available
# 4     Not Available    Not Available          1474.37           Not Available
# 5     Not Available    Not Available           1418.6           Not Available
#
#   Biofuel_consumption Total_Biomass_Consumption Total_Renewable_Consumption
# 1       Not Available                   1549.26                     2973.98
# 2       Not Available                   1562.31                     2977.72
# 3       Not Available                   1534.67                     2958.46
# 4       Not Available                   1474.37                     2940.18
# 5       Not Available                    1418.6                     2831.46

# %%
energy_prod['Year'] = energy_prod['Year'].astype(int)

# %%
#Replace Not available with zeros
energy_prod = energy_prod.replace('Not Available', 0)

# %%
energy_prod.head()
# Out:
#    Year  Wood_production  Biofuel_Production  Total_Biomass_Prod  \
# 1  1949         1549.262                 0.0            1549.262
# 2  1950         1562.307                 0.0            1562.307
# 3  1951         1534.669                 0.0            1534.669
# 4  1952         1474.369                 0.0            1474.369
# 5  1953         1418.601                 0.0            1418.601
#
#    Total_Renewable_Production  Hydro_consumption  Geo_Consumption  \
# 1                    2973.984           1424.722              0.0
# 2                    2977.718           1415.411              0.0
# 3                    2958.464           1423.795              0.0
# 4                    2940.181           1465.812              0.0
# 5                    2831.460           1412.859              0.0
#
#    Solar_Consumption  Wind_Consumption  Wood_Consumption  \
# 1                0.0               0.0          1549.262
# 2                0.0               0.0          1562.307
# 3                0.0               0.0          1534.669
# 4                0.0               0.0          1474.369
# 5                0.0               0.0          1418.601
#
#    WasteEnergy_Consumption  Biofuel_consumption  Total_Biomass_Consumption  \
# 1                      0.0                  0.0                   1549.262
# 2                      0.0                  0.0                   1562.307
# 3                      0.0                  0.0                   1534.669
# 4                      0.0                  0.0                   1474.369
# 5                      0.0                  0.0                   1418.601
#
#    Total_Renewable_Consumption
# 1                     2973.984
# 2                     2977.718
# 3                     2958.464
# 4                     2940.181
# 5                     2831.460

# %%
# energy_prod.tail(30)

# %%
energy_cons['Total_primary_Cosumption']
# Out:
# 1      31.967775
# 2      34.598567
# 3      36.953661
# 4      36.726037
# 5      37.640598
#          ...
# 67     97.375221
# 68     97.335208
# 69     97.594743
# 70    101.161852
# 71    100.273806
# Name: Total_primary_Cosumption, Length: 71, dtype: float64

# %%
#  Quadrillion                                     Trillion
energy_prod['Total_Energy_Consumption'] = energy_cons['Total_primary_Cosumption']
energy_prod
# Out:
#     Year  Wood_production  Biofuel_Production  Total_Biomass_Prod  \
# 1   1949         1549.262               0.000            1549.262
# 2   1950         1562.307               0.000            1562.307
# 3   1951         1534.669               0.000            1534.669
# 4   1952         1474.369               0.000            1474.369
# 5   1953         1418.601               0.000            1418.601
# ..   ...              ...                 ...                 ...
# 67  2015         2311.768            2161.440            4991.579
# 68  2016         2296.696            2274.948            5074.863
# 69  2017         2259.189            2344.298            5098.747
# 70  2018         2354.564            2396.573            5238.484
# 71  2019         2330.279            2327.517            5100.242
#
#     Total_Renewable_Production  Hydro_consumption  Geo_Consumption  \
# 1                     2973.984           1424.722            0.000
# 2                     2977.718           1415.411            0.000
# 3                     2958.464           1423.795            0.000
# 4                     2940.181           1465.812            0.000
# 5                     2831.460           1412.859            0.000
# ..                         ...                ...              ...
# 67                    9728.765           2321.177          211.836
# 68                   10422.872           2472.442          209.604
# 69                   11195.923           2766.967          210.233
# 70                   11508.364           2663.138          208.865
# 71                   11508.598           2563.228          201.269
#
#     Solar_Consumption  Wind_Consumption  Wood_Consumption  \
# 1               0.000             0.000          1549.262
# 2               0.000             0.000          1562.307
# 3               0.000             0.000          1534.669
# 4               0.000             0.000          1474.369
# 5               0.000             0.000          1418.601
# ..                ...               ...               ...
# 67            426.867          1777.306          2311.768
# 68            570.368          2095.595          2224.121
# 69            777.084          2342.891          2180.563
# 70            915.513          2482.364          2260.506
# 71           1018.013          2625.846          2226.635
#
#     WasteEnergy_Consumption  Biofuel_consumption  Total_Biomass_Consumption  \
# 1                     0.000                0.000                   1549.262
# 2                     0.000                0.000                   1562.307
# 3                     0.000                0.000                   1534.669
# 4                     0.000                0.000                   1474.369
# 5                     0.000                0.000                   1418.601
# ..                      ...                  ...                        ...
# 67                  518.371             2153.219                   4983.358
# 68                  503.219             2287.182                   5014.521
# 69                  495.260             2303.518                   4979.340
# 70                  487.347             2283.247                   5031.100
# 71                  442.447             2254.725                   4923.807
#
#     Total_Renewable_Consumption  Total_Energy_Consumption
# 1                      2973.984                 31.967775
# 2                      2977.718                 34.598567
# 3                      2958.464                 36.953661
# 4                      2940.181                 36.726037
# 5                      2831.460                 37.640598
# ..                          ...                       ...
# 67                     9720.544                 97.375221
# 68                    10362.530                 97.335208
# 69                    11076.515                 97.594743
# 70                    11300.980                101.161852
# 71                    11332.162                100.273806
#
# [71 rows x 15 columns]

# %%
# Convert the quadrillion to Trillion
energy_prod['Total_Energy_Consumption'] = energy_prod['Total_Energy_Consumption'] * 1000

# %%
energy_prod.head()
# Out:
#    Year  Wood_production  Biofuel_Production  Total_Biomass_Prod  \
# 1  1949         1549.262                 0.0            1549.262
# 2  1950         1562.307                 0.0            1562.307
# 3  1951         1534.669                 0.0            1534.669
# 4  1952         1474.369                 0.0            1474.369
# 5  1953         1418.601                 0.0            1418.601
#
#    Total_Renewable_Production  Hydro_consumption  Geo_Consumption  \
# 1                    2973.984           1424.722              0.0
# 2                    2977.718           1415.411              0.0
# 3                    2958.464           1423.795              0.0
# 4                    2940.181           1465.812              0.0
# 5                    2831.460           1412.859              0.0
#
#    Solar_Consumption  Wind_Consumption  Wood_Consumption  \
# 1                0.0               0.0          1549.262
# 2                0.0               0.0          1562.307
# 3                0.0               0.0          1534.669
# 4                0.0               0.0          1474.369
# 5                0.0               0.0          1418.601
#
#    WasteEnergy_Consumption  Biofuel_consumption  Total_Biomass_Consumption  \
# 1                      0.0                  0.0                   1549.262
# 2                      0.0                  0.0                   1562.307
# 3                      0.0                  0.0                   1534.669
# 4                      0.0                  0.0                   1474.369
# 5                      0.0                  0.0                   1418.601
#
#    Total_Renewable_Consumption  Total_Energy_Consumption
# 1                     2973.984                 31967.775
# 2                     2977.718                 34598.567
# 3                     2958.464                 36953.661
# 4                     2940.181                 36726.037
# 5                     2831.460                 37640.598

# %%
energy_prod['Total_Renewable_Production_Twh'] = energy_prod['Total_Renewable_Production'] * .293071070172222
energy_prod['Total_Renewable_Consumption_Twh'] = energy_prod['Total_Renewable_Consumption'] * .293071070172222
energy_prod['Total_Energy_Consumption_Twh'] = energy_prod['Total_Energy_Consumption'] * .293071070172222

# %%
energy_prod
# Out:
#     Year  Wood_production  Biofuel_Production  Total_Biomass_Prod  \
# 1   1949         1549.262               0.000            1549.262
# 2   1950         1562.307               0.000            1562.307
# 3   1951         1534.669               0.000            1534.669
# 4   1952         1474.369               0.000            1474.369
# 5   1953         1418.601               0.000            1418.601
# ..   ...              ...                 ...                 ...
# 67  2015         2311.768            2161.440            4991.579
# 68  2016         2296.696            2274.948            5074.863
# 69  2017         2259.189            2344.298            5098.747
# 70  2018         2354.564            2396.573            5238.484
# 71  2019         2330.279            2327.517            5100.242
#
#     Total_Renewable_Production  Hydro_consumption  Geo_Consumption  \
# 1                     2973.984           1424.722            0.000
# 2                     2977.718           1415.411            0.000
# 3                     2958.464           1423.795            0.000
# 4                     2940.181           1465.812            0.000
# 5                     2831.460           1412.859            0.000
# ..                         ...                ...              ...
# 67                    9728.765           2321.177          211.836
# 68                   10422.872           2472.442          209.604
# 69                   11195.923           2766.967          210.233
# 70                   11508.364           2663.138          208.865
# 71                   11508.598           2563.228          201.269
#
#     Solar_Consumption  Wind_Consumption  Wood_Consumption  \
# 1               0.000             0.000          1549.262
# 2               0.000             0.000          1562.307
# 3               0.000             0.000          1534.669
# 4               0.000             0.000          1474.369
# 5               0.000             0.000          1418.601
# ..                ...               ...               ...
# 67            426.867          1777.306          2311.768
# 68            570.368          2095.595          2224.121
# 69            777.084          2342.891          2180.563
# 70            915.513          2482.364          2260.506
# 71           1018.013          2625.846          2226.635
#
#     WasteEnergy_Consumption  Biofuel_consumption  Total_Biomass_Consumption  \
# 1                     0.000                0.000                   1549.262
# 2                     0.000                0.000                   1562.307
# 3                     0.000                0.000                   1534.669
# 4                     0.000                0.000                   1474.369
# 5                     0.000                0.000                   1418.601
# ..                      ...                  ...                        ...
# 67                  518.371             2153.219                   4983.358
# 68                  503.219             2287.182                   5014.521
# 69                  495.260             2303.518                   4979.340
# 70                  487.347             2283.247                   5031.100
# 71                  442.447             2254.725                   4923.807
#
#     Total_Renewable_Consumption  Total_Energy_Consumption  \
# 1                      2973.984                 31967.775
# 2                      2977.718                 34598.567
# 3                      2958.464                 36953.661
# 4                      2940.181                 36726.037
# 5                      2831.460                 37640.598
# ..                          ...                       ...
# 67                     9720.544                 97375.221
# 68                    10362.530                 97335.208
# 69                    11076.515                 97594.743
# 70                    11300.980                101161.852
# 71                    11332.162                100273.806
#
#     Total_Renewable_Production_Twh  Total_Renewable_Consumption_Twh  \
# 1                       871.588674                       871.588674
# 2                       872.683001                       872.683001
# 3                       867.040211                       867.040211
# 4                       861.681992                       861.681992
# 5                       829.819012                       829.819012
# ..                             ...                              ...
# 67                     2851.219570                      2848.810233
# 68                     3054.642251                      3036.957757
# 69                     3281.201135                      3246.206105
# 70                     3372.768553                      3311.990303
# 71                     3372.837132                      3321.128845
#
#     Total_Energy_Consumption_Twh
# 1                    9368.830030
# 2                   10139.839057
# 3                   10830.048976
# 4                   10763.338967
# 5                   11031.370338
# ..                           ...
# 67                  28537.860227
# 68                  28526.133574
# 69                  28602.195774
# 70                  29647.612226
# 71                  29387.351635
#
# [71 rows x 18 columns]

# %% [markdown]
# # Connect and Update to Mongo

# %%
import pymongo
from pymongo import MongoClient

# conn = 'mongodb://localhost:27017'

# #     conn = f'mongodb+srv://{username}:{password}@cluster0.zdhdq.mongodb.net/{dbname}?retryWrites=true&w=majority'
# client = MongoClient(conn)

# # Define the Database in Mongo
# db = client.renewable_energy

# collection = db[collectionName]
# gdp_cons = energy_cons1.to_dict('records')
# collection.insert_many(gdp_cons)

# %% [markdown]
# ### Energy consumption collection created in mongo

# %%
#Default port used by MongoDB is 27017
conn='mongodb://localhost:27017'
client=pymongo.MongoClient(conn)
#Decleare the database
db=client['renewable_energy']

# %%
#Declare the collection
col_engcons=db['energyconsumption']

df=energy_cons.to_dict('records')
col_engcons.insert_many(df)

# %%
for row in db.energyconsumption.find():
    pprint(row)
    print("------------------------")
# Out:
# {'Bio_Consumption': 1.549262,
#  'Coal_Consumption': 11.980905,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 28.988371,
#  'Gas_Consumption': 5.145142,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.424722,
#  'Petro_Consumption': 11.868994,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.973984,
#  'Total_primary_Cosumption': 31.967775,
#  'Wind_Consumption': 0.0,
#  'Year': 1949,
#  '_id': ObjectId('5fc69f45b7abff5a7656b754')}
# ------------------------
# {'Bio_Consumption': 1.562307,
#  'Coal_Consumption': 12.347109,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 31.614755,
#  'Gas_Consumption': 5.968371,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.415411,
#  'Petro_Consumption': 13.298283,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.977718,
#  'Total_primary_Cosumption': 34.598567,
#  'Wind_Consumption': 0.0,
#  'Year': 1950,
#  '_id': ObjectId('5fc69f45b7abff5a7656b755')}
# ------------------------
# {'Bio_Consumption': 1.534669,
#  'Coal_Consumption': 12.552996,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 33.987736,
#  'Gas_Consumption': 7.048518,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.423795,
#  'Petro_Consumption': 14.407674,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.958464,
#  'Total_primary_Cosumption': 36.953661,
#  'Wind_Consumption': 0.0,
#  'Year': 1951,
#  '_id': ObjectId('5fc69f45b7abff5a7656b756')}
# ------------------------
# {'Bio_Consumption': 1.474369,
#  'Coal_Consumption': 11.306479,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 33.778116,
#  'Gas_Consumption': 7.549621,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.465812,
#  'Petro_Consumption': 14.933895,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.940181,
#  'Total_primary_Cosumption': 36.726037,
#  'Wind_Consumption': 0.0,
#  'Year': 1952,
#  '_id': ObjectId('5fc69f45b7abff5a7656b757')}
# ------------------------
# {'Bio_Consumption': 1.418601,
#  'Coal_Consumption': 11.372684,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 34.802286,
#  'Gas_Consumption': 7.906645,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.412859,
#  'Petro_Consumption': 15.531959,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.83146,
#  'Total_primary_Cosumption': 37.640598,
#  'Wind_Consumption': 0.0,
#  'Year': 1953,
#  '_id': ObjectId('5fc69f45b7abff5a7656b758')}
# ------------------------
# {'Bio_Consumption': 1.394327,
#  'Coal_Consumption': 9.714667,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 33.851458,
#  'Gas_Consumption': 8.330202,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.359772,
#  'Petro_Consumption': 15.813334,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.754099,
#  'Total_primary_Cosumption': 36.61354,
#  'Wind_Consumption': 0.0,
#  'Year': 1954,
#  '_id': ObjectId('5fc69f45b7abff5a7656b759')}
# ------------------------
# {'Bio_Consumption': 1.424143,
#  'Coal_Consumption': 11.167259,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 37.380419,
#  'Gas_Consumption': 8.997935,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.359844,
#  'Petro_Consumption': 17.225269,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.783987,
#  'Total_primary_Cosumption': 40.178285,
#  'Wind_Consumption': 0.0,
#  'Year': 1955,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75a')}
# ------------------------
# {'Bio_Consumption': 1.415871,
#  'Coal_Consumption': 11.349723,
#  'Electric_consumption': 0.0,
#  'Fossil_Consumption': 38.855656,
#  'Gas_Consumption': 9.613975,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.434711,
#  'Petro_Consumption': 17.904978,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.850582,
#  'Total_primary_Cosumption': 41.721757,
#  'Wind_Consumption': 0.0,
#  'Year': 1956,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75b')}
# ------------------------
# {'Bio_Consumption': 1.333581,
#  'Coal_Consumption': 10.820631,
#  'Electric_consumption': 0.000112,
#  'Fossil_Consumption': 38.892315,
#  'Gas_Consumption': 10.190753,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.515613,
#  'Petro_Consumption': 17.89839,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.849194,
#  'Total_primary_Cosumption': 41.753909,
#  'Wind_Consumption': 0.0,
#  'Year': 1957,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75c')}
# ------------------------
# {'Bio_Consumption': 1.323123,
#  'Coal_Consumption': 9.533287,
#  'Electric_consumption': 0.001915,
#  'Fossil_Consumption': 38.680955,
#  'Gas_Consumption': 10.663199,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.591967,
#  'Petro_Consumption': 18.49119,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.91509,
#  'Total_primary_Cosumption': 41.60928,
#  'Wind_Consumption': 0.0,
#  'Year': 1958,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75d')}
# ------------------------
# {'Bio_Consumption': 1.352874,
#  'Coal_Consumption': 9.518353,
#  'Electric_consumption': 0.002187,
#  'Fossil_Consumption': 40.507312,
#  'Gas_Consumption': 11.717422,
#  'Geo_Consumption': 0.0,
#  'Hydro_Consumption': 1.548465,
#  'Petro_Consumption': 19.279894,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.901339,
#  'Total_primary_Cosumption': 43.422965,
#  'Wind_Consumption': 0.0,
#  'Year': 1959,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75e')}
# ------------------------
# {'Bio_Consumption': 1.31987,
#  'Coal_Consumption': 9.837785,
#  'Electric_consumption': 0.006026,
#  'Fossil_Consumption': 42.091028,
#  'Gas_Consumption': 12.385366,
#  'Geo_Consumption': 0.000359,
#  'Hydro_Consumption': 1.607975,
#  'Petro_Consumption': 19.873507,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.928204,
#  'Total_primary_Cosumption': 45.040732,
#  'Wind_Consumption': 0.0,
#  'Year': 1960,
#  '_id': ObjectId('5fc69f45b7abff5a7656b75f')}
# ------------------------
# {'Bio_Consumption': 1.294762,
#  'Coal_Consumption': 9.623351,
#  'Electric_consumption': 0.019678,
#  'Fossil_Consumption': 42.711189,
#  'Gas_Consumption': 12.926392,
#  'Geo_Consumption': 0.001001,
#  'Hydro_Consumption': 1.656463,
#  'Petro_Consumption': 20.169333,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 2.952226,
#  'Total_primary_Cosumption': 45.690782,
#  'Wind_Consumption': 0.0,
#  'Year': 1961,
#  '_id': ObjectId('5fc69f45b7abff5a7656b760')}
# ------------------------
# {'Bio_Consumption': 1.300242,
#  'Coal_Consumption': 9.906454,
#  'Electric_consumption': 0.026394,
#  'Fossil_Consumption': 44.62938,
#  'Gas_Consumption': 13.730841,
#  'Geo_Consumption': 0.001061,
#  'Hydro_Consumption': 1.816141,
#  'Petro_Consumption': 20.997591,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.117444,
#  'Total_primary_Cosumption': 47.775047,
#  'Wind_Consumption': 0.0,
#  'Year': 1962,
#  '_id': ObjectId('5fc69f45b7abff5a7656b761')}
# ------------------------
# {'Bio_Consumption': 1.323316,
#  'Coal_Consumption': 10.412538,
#  'Electric_consumption': 0.038147,
#  'Fossil_Consumption': 46.45372,
#  'Gas_Consumption': 14.403306,
#  'Geo_Consumption': 0.00176,
#  'Hydro_Consumption': 1.771355,
#  'Petro_Consumption': 21.645265,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.096431,
#  'Total_primary_Cosumption': 49.588632,
#  'Wind_Consumption': 0.0,
#  'Year': 1963,
#  '_id': ObjectId('5fc69f45b7abff5a7656b762')}
# ------------------------
# {'Bio_Consumption': 1.336802,
#  'Coal_Consumption': 10.964385,
#  'Electric_consumption': 0.039819,
#  'Fossil_Consumption': 48.483687,
#  'Gas_Consumption': 15.28785,
#  'Geo_Consumption': 0.002132,
#  'Hydro_Consumption': 1.886314,
#  'Petro_Consumption': 22.241894,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.225248,
#  'Total_primary_Cosumption': 51.755425,
#  'Wind_Consumption': 0.0,
#  'Year': 1964,
#  '_id': ObjectId('5fc69f45b7abff5a7656b763')}
# ------------------------
# {'Bio_Consumption': 1.334761,
#  'Coal_Consumption': 11.580608,
#  'Electric_consumption': 0.043164,
#  'Fossil_Consumption': 50.514724,
#  'Gas_Consumption': 15.768667,
#  'Geo_Consumption': 0.001978,
#  'Hydro_Consumption': 2.059077,
#  'Petro_Consumption': 23.1839,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.395816,
#  'Total_primary_Cosumption': 53.953222,
#  'Wind_Consumption': 0.0,
#  'Year': 1965,
#  '_id': ObjectId('5fc69f45b7abff5a7656b764')}
# ------------------------
# {'Bio_Consumption': 1.368985,
#  'Coal_Consumption': 12.14308,
#  'Electric_consumption': 0.064158,
#  'Fossil_Consumption': 53.448822,
#  'Gas_Consumption': 16.995332,
#  'Geo_Consumption': 0.001958,
#  'Hydro_Consumption': 2.061519,
#  'Petro_Consumption': 24.335358,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.432462,
#  'Total_primary_Cosumption': 56.949167,
#  'Wind_Consumption': 0.0,
#  'Year': 1966,
#  '_id': ObjectId('5fc69f45b7abff5a7656b765')}
# ------------------------
# {'Bio_Consumption': 1.340249,
#  'Coal_Consumption': 11.91375,
#  'Electric_consumption': 0.088456,
#  'Fossil_Consumption': 55.117171,
#  'Gas_Consumption': 17.944788,
#  'Geo_Consumption': 0.0033,
#  'Hydro_Consumption': 2.346664,
#  'Petro_Consumption': 25.273959,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.690213,
#  'Total_primary_Cosumption': 58.89482,
#  'Wind_Consumption': 0.0,
#  'Year': 1967,
#  '_id': ObjectId('5fc69f45b7abff5a7656b766')}
# ------------------------
# {'Bio_Consumption': 1.419495,
#  'Coal_Consumption': 12.330677,
#  'Electric_consumption': 0.141534,
#  'Fossil_Consumption': 58.489442,
#  'Gas_Consumption': 19.209656,
#  'Geo_Consumption': 0.004532,
#  'Hydro_Consumption': 2.348629,
#  'Petro_Consumption': 26.966419,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 3.772656,
#  'Total_primary_Cosumption': 62.40148,
#  'Wind_Consumption': 0.0,
#  'Year': 1968,
#  '_id': ObjectId('5fc69f45b7abff5a7656b767')}
# ------------------------
# {'Bio_Consumption': 1.440487,
#  'Coal_Consumption': 12.38154,
#  'Electric_consumption': 0.153722,
#  'Fossil_Consumption': 61.343989,
#  'Gas_Consumption': 20.677984,
#  'Geo_Consumption': 0.006422,
#  'Hydro_Consumption': 2.647983,
#  'Petro_Consumption': 28.320574,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.094892,
#  'Total_primary_Cosumption': 65.596259,
#  'Wind_Consumption': 0.0,
#  'Year': 1969,
#  '_id': ObjectId('5fc69f45b7abff5a7656b768')}
# ------------------------
# {'Bio_Consumption': 1.430962,
#  'Coal_Consumption': 12.264528,
#  'Electric_consumption': 0.239347,
#  'Fossil_Consumption': 63.500772,
#  'Gas_Consumption': 21.794707,
#  'Geo_Consumption': 0.005511,
#  'Hydro_Consumption': 2.633547,
#  'Petro_Consumption': 29.499198,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.070021,
#  'Total_primary_Cosumption': 67.816828,
#  'Wind_Consumption': 0.0,
#  'Year': 1970,
#  '_id': ObjectId('5fc69f45b7abff5a7656b769')}
# ------------------------
# {'Bio_Consumption': 1.432323,
#  'Coal_Consumption': 11.598411,
#  'Electric_consumption': 0.412939,
#  'Fossil_Consumption': 64.573073,
#  'Gas_Consumption': 22.469052,
#  'Geo_Consumption': 0.005739,
#  'Hydro_Consumption': 2.824151,
#  'Petro_Consumption': 30.538718,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.262213,
#  'Total_primary_Cosumption': 69.260271,
#  'Wind_Consumption': 0.0,
#  'Year': 1971,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76a')}
# ------------------------
# {'Bio_Consumption': 1.503065,
#  'Coal_Consumption': 12.076917,
#  'Electric_consumption': 0.583752,
#  'Fossil_Consumption': 67.668048,
#  'Gas_Consumption': 22.69819,
#  'Geo_Consumption': 0.015079,
#  'Hydro_Consumption': 2.863865,
#  'Petro_Consumption': 32.918906,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.382009,
#  'Total_primary_Cosumption': 72.660036,
#  'Wind_Consumption': 0.0,
#  'Year': 1972,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76b')}
# ------------------------
# {'Bio_Consumption': 1.529068,
#  'Coal_Consumption': 12.97149,
#  'Electric_consumption': 0.910177,
#  'Fossil_Consumption': 70.28245,
#  'Gas_Consumption': 22.512399,
#  'Geo_Consumption': 0.020422,
#  'Hydro_Consumption': 2.861448,
#  'Petro_Consumption': 34.806025,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.410938,
#  'Total_primary_Cosumption': 75.65228,
#  'Wind_Consumption': 0.0,
#  'Year': 1973,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76c')}
# ------------------------
# {'Bio_Consumption': 1.539662,
#  'Coal_Consumption': 12.662878,
#  'Electric_consumption': 1.272083,
#  'Fossil_Consumption': 67.872076,
#  'Gas_Consumption': 21.732488,
#  'Geo_Consumption': 0.02561,
#  'Hydro_Consumption': 3.17658,
#  'Petro_Consumption': 33.420613,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.741852,
#  'Total_primary_Cosumption': 73.929322,
#  'Wind_Consumption': 0.0,
#  'Year': 1974,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76d')}
# ------------------------
# {'Bio_Consumption': 1.498734,
#  'Coal_Consumption': 12.662786,
#  'Electric_consumption': 1.899798,
#  'Fossil_Consumption': 65.32299,
#  'Gas_Consumption': 19.947883,
#  'Geo_Consumption': 0.03378,
#  'Hydro_Consumption': 3.154607,
#  'Petro_Consumption': 32.698781,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.68712,
#  'Total_primary_Cosumption': 71.931011,
#  'Wind_Consumption': 0.0,
#  'Year': 1975,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76e')}
# ------------------------
# {'Bio_Consumption': 1.713373,
#  'Coal_Consumption': 13.584067,
#  'Electric_consumption': 2.111121,
#  'Fossil_Consumption': 69.071379,
#  'Gas_Consumption': 20.345426,
#  'Geo_Consumption': 0.037513,
#  'Hydro_Consumption': 2.976265,
#  'Petro_Consumption': 35.141985,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.727151,
#  'Total_primary_Cosumption': 75.939029,
#  'Wind_Consumption': 0.0,
#  'Year': 1976,
#  '_id': ObjectId('5fc69f45b7abff5a7656b76f')}
# ------------------------
# {'Bio_Consumption': 1.838332,
#  'Coal_Consumption': 13.922103,
#  'Electric_consumption': 2.701762,
#  'Fossil_Consumption': 70.949841,
#  'Gas_Consumption': 19.930513,
#  'Geo_Consumption': 0.037382,
#  'Hydro_Consumption': 2.333252,
#  'Petro_Consumption': 37.082642,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 4.208966,
#  'Total_primary_Cosumption': 77.919991,
#  'Wind_Consumption': 0.0,
#  'Year': 1977,
#  '_id': ObjectId('5fc69f45b7abff5a7656b770')}
# ------------------------
# {'Bio_Consumption': 2.037605,
#  'Coal_Consumption': 13.765575,
#  'Electric_consumption': 3.024126,
#  'Fossil_Consumption': 71.80982,
#  'Gas_Consumption': 20.0004,
#  'Geo_Consumption': 0.030851,
#  'Hydro_Consumption': 2.936983,
#  'Petro_Consumption': 37.919119,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 5.00544,
#  'Total_primary_Cosumption': 79.906703,
#  'Wind_Consumption': 0.0,
#  'Year': 1978,
#  '_id': ObjectId('5fc69f45b7abff5a7656b771')}
# ------------------------
# {'Bio_Consumption': 2.151906,
#  'Coal_Consumption': 15.039586,
#  'Electric_consumption': 2.775827,
#  'Fossil_Consumption': 72.843726,
#  'Gas_Consumption': 20.665817,
#  'Geo_Consumption': 0.040262,
#  'Hydro_Consumption': 2.930686,
#  'Petro_Consumption': 37.075478,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 5.122854,
#  'Total_primary_Cosumption': 80.811788,
#  'Wind_Consumption': 0.0,
#  'Year': 1979,
#  '_id': ObjectId('5fc69f45b7abff5a7656b772')}
# ------------------------
# {'Bio_Consumption': 2.4755,
#  'Coal_Consumption': 15.422809,
#  'Electric_consumption': 2.739169,
#  'Fossil_Consumption': 69.782203,
#  'Gas_Consumption': 20.235459,
#  'Geo_Consumption': 0.052699,
#  'Hydro_Consumption': 2.900144,
#  'Petro_Consumption': 34.158965,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 5.428342,
#  'Total_primary_Cosumption': 78.021113,
#  'Wind_Consumption': 0.0,
#  'Year': 1980,
#  '_id': ObjectId('5fc69f45b7abff5a7656b773')}
# ------------------------
# {'Bio_Consumption': 2.596283,
#  'Coal_Consumption': 15.907526,
#  'Electric_consumption': 3.007589,
#  'Fossil_Consumption': 67.522504,
#  'Gas_Consumption': 19.74731,
#  'Geo_Consumption': 0.059437,
#  'Hydro_Consumption': 2.757968,
#  'Petro_Consumption': 31.883616,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 5.413688,
#  'Total_primary_Cosumption': 76.057187,
#  'Wind_Consumption': 0.0,
#  'Year': 1981,
#  '_id': ObjectId('5fc69f45b7abff5a7656b774')}
# ------------------------
# {'Bio_Consumption': 2.663452,
#  'Coal_Consumption': 15.321581,
#  'Electric_consumption': 3.131148,
#  'Fossil_Consumption': 63.835377,
#  'Gas_Consumption': 18.356222,
#  'Geo_Consumption': 0.050627,
#  'Hydro_Consumption': 3.265558,
#  'Petro_Consumption': 30.17923,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 5.979637,
#  'Total_primary_Cosumption': 73.046189,
#  'Wind_Consumption': 0.0,
#  'Year': 1982,
#  '_id': ObjectId('5fc69f45b7abff5a7656b775')}
# ------------------------
# {'Bio_Consumption': 2.904414,
#  'Coal_Consumption': 15.894442,
#  'Electric_consumption': 3.202549,
#  'Fossil_Consumption': 63.096686,
#  'Gas_Consumption': 17.220836,
#  'Geo_Consumption': 0.06391,
#  'Hydro_Consumption': 3.52726,
#  'Petro_Consumption': 29.997044,
#  'Solar_Consumption': 0.0,
#  'Total_Renewable_Consumption': 6.495612,
#  'Total_primary_Cosumption': 72.915394,
#  'Wind_Consumption': 2.8e-05,
#  'Year': 1983,
#  '_id': ObjectId('5fc69f45b7abff5a7656b776')}
# ------------------------
# {'Bio_Consumption': 2.97112,
#  'Coal_Consumption': 17.070622,
#  'Electric_consumption': 3.552531,
#  'Fossil_Consumption': 66.444979,
#  'Gas_Consumption': 18.393613,
#  'Geo_Consumption': 0.080811,
#  'Hydro_Consumption': 3.385811,
#  'Petro_Consumption': 30.992232,
#  'Solar_Consumption': 5.5e-05,
#  'Total_Renewable_Consumption': 6.437864,
#  'Total_primary_Cosumption': 76.570697,
#  'Wind_Consumption': 6.8e-05,
#  'Year': 1984,
#  '_id': ObjectId('5fc69f45b7abff5a7656b777')}
# ------------------------
# {'Bio_Consumption': 3.016233,
#  'Coal_Consumption': 17.478428,
#  'Electric_consumption': 4.075563,
#  'Fossil_Consumption': 66.0349,
#  'Gas_Consumption': 17.703482,
#  'Geo_Consumption': 0.097421,
#  'Hydro_Consumption': 2.970192,
#  'Petro_Consumption': 30.866482,
#  'Solar_Consumption': 0.000111,
#  'Total_Renewable_Consumption': 6.084017,
#  'Total_primary_Cosumption': 76.334135,
#  'Wind_Consumption': 6e-05,
#  'Year': 1985,
#  '_id': ObjectId('5fc69f45b7abff5a7656b778')}
# ------------------------
# {'Bio_Consumption': 2.932095,
#  'Coal_Consumption': 17.260405,
#  'Electric_consumption': 4.380109,
#  'Fossil_Consumption': 65.985158,
#  'Gas_Consumption': 16.591364,
#  'Geo_Consumption': 0.107677,
#  'Hydro_Consumption': 3.071179,
#  'Petro_Consumption': 32.150143,
#  'Solar_Consumption': 0.000147,
#  'Total_Renewable_Consumption': 6.11114,
#  'Total_primary_Cosumption': 76.598888,
#  'Wind_Consumption': 4.4e-05,
#  'Year': 1986,
#  '_id': ObjectId('5fc69f45b7abff5a7656b779')}
# ------------------------
# {'Bio_Consumption': 2.874884,
#  'Coal_Consumption': 18.008451,
#  'Electric_consumption': 4.753933,
#  'Fossil_Consumption': 68.474361,
#  'Gas_Consumption': 17.639801,
#  'Geo_Consumption': 0.11227,
#  'Hydro_Consumption': 2.634508,
#  'Petro_Consumption': 32.817479,
#  'Solar_Consumption': 0.000109,
#  'Total_Renewable_Consumption': 5.621807,
#  'Total_primary_Cosumption': 79.008203,
#  'Wind_Consumption': 3.7e-05,
#  'Year': 1987,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77a')}
# ------------------------
# {'Bio_Consumption': 3.016049,
#  'Coal_Consumption': 18.846312,
#  'Electric_consumption': 5.586968,
#  'Fossil_Consumption': 71.507048,
#  'Gas_Consumption': 18.448393,
#  'Geo_Consumption': 0.106338,
#  'Hydro_Consumption': 2.334265,
#  'Petro_Consumption': 34.172792,
#  'Solar_Consumption': 9.4e-05,
#  'Total_Renewable_Consumption': 5.456754,
#  'Total_primary_Cosumption': 82.659169,
#  'Wind_Consumption': 9e-06,
#  'Year': 1988,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77b')}
# ------------------------
# {'Bio_Consumption': 3.159357,
#  'Coal_Consumption': 19.069762,
#  'Electric_consumption': 5.602161,
#  'Fossil_Consumption': 72.865725,
#  'Gas_Consumption': 19.601606,
#  'Geo_Consumption': 0.161539,
#  'Hydro_Consumption': 2.837263,
#  'Petro_Consumption': 34.163952,
#  'Solar_Consumption': 0.054466,
#  'Total_Renewable_Consumption': 6.234658,
#  'Total_primary_Cosumption': 84.739993,
#  'Wind_Consumption': 0.022033,
#  'Year': 1989,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77c')}
# ------------------------
# {'Bio_Consumption': 2.735112,
#  'Coal_Consumption': 19.172635,
#  'Electric_consumption': 6.10435,
#  'Fossil_Consumption': 72.280598,
#  'Gas_Consumption': 19.603267,
#  'Geo_Consumption': 0.170747,
#  'Hydro_Consumption': 3.046391,
#  'Petro_Consumption': 33.499918,
#  'Solar_Consumption': 0.058768,
#  'Total_Renewable_Consumption': 6.040024,
#  'Total_primary_Cosumption': 84.43286,
#  'Wind_Consumption': 0.029007,
#  'Year': 1990,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77d')}
# ------------------------
# {'Bio_Consumption': 2.781797,
#  'Coal_Consumption': 18.99167,
#  'Electric_consumption': 6.422132,
#  'Fossil_Consumption': 71.823417,
#  'Gas_Consumption': 20.032958,
#  'Geo_Consumption': 0.177626,
#  'Hydro_Consumption': 3.015943,
#  'Petro_Consumption': 32.789101,
#  'Solar_Consumption': 0.061623,
#  'Total_Renewable_Consumption': 6.067785,
#  'Total_primary_Cosumption': 84.3803,
#  'Wind_Consumption': 0.030796,
#  'Year': 1991,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77e')}
# ------------------------
# {'Bio_Consumption': 2.931678,
#  'Coal_Consumption': 19.122471,
#  'Electric_consumption': 6.479206,
#  'Fossil_Consumption': 73.338389,
#  'Gas_Consumption': 20.713632,
#  'Geo_Consumption': 0.178699,
#  'Hydro_Consumption': 2.617436,
#  'Petro_Consumption': 33.467661,
#  'Solar_Consumption': 0.06288,
#  'Total_Renewable_Consumption': 5.820556,
#  'Total_primary_Cosumption': 85.724885,
#  'Wind_Consumption': 0.029863,
#  'Year': 1992,
#  '_id': ObjectId('5fc69f45b7abff5a7656b77f')}
# ------------------------
# {'Bio_Consumption': 2.908172,
#  'Coal_Consumption': 19.835148,
#  'Electric_consumption': 6.410499,
#  'Fossil_Consumption': 74.678844,
#  'Gas_Consumption': 21.229,
#  'Geo_Consumption': 0.185673,
#  'Hydro_Consumption': 2.891613,
#  'Petro_Consumption': 33.587587,
#  'Solar_Consumption': 0.06519,
#  'Total_Renewable_Consumption': 6.081635,
#  'Total_primary_Cosumption': 87.265888,
#  'Wind_Consumption': 0.030987,
#  'Year': 1993,
#  '_id': ObjectId('5fc69f45b7abff5a7656b780')}
# ------------------------
# {'Bio_Consumption': 3.027534,
#  'Coal_Consumption': 19.909463,
#  'Electric_consumption': 6.693877,
#  'Fossil_Consumption': 76.149278,
#  'Gas_Consumption': 21.728067,
#  'Geo_Consumption': 0.173464,
#  'Hydro_Consumption': 2.683457,
#  'Petro_Consumption': 34.45342,
#  'Solar_Consumption': 0.067126,
#  'Total_Renewable_Consumption': 5.987142,
#  'Total_primary_Cosumption': 88.983234,
#  'Wind_Consumption': 0.03556,
#  'Year': 1994,
#  '_id': ObjectId('5fc69f45b7abff5a7656b781')}
# ------------------------
# {'Bio_Consumption': 3.101142,
#  'Coal_Consumption': 20.088727,
#  'Electric_consumption': 7.075436,
#  'Fossil_Consumption': 77.162044,
#  'Gas_Consumption': 22.671139,
#  'Geo_Consumption': 0.152057,
#  'Hydro_Consumption': 3.205307,
#  'Petro_Consumption': 34.341117,
#  'Solar_Consumption': 0.068233,
#  'Total_Renewable_Consumption': 6.559369,
#  'Total_primary_Cosumption': 90.930704,
#  'Wind_Consumption': 0.03263,
#  'Year': 1995,
#  '_id': ObjectId('5fc69f45b7abff5a7656b782')}
# ------------------------
# {'Bio_Consumption': 3.156806,
#  'Coal_Consumption': 21.001914,
#  'Electric_consumption': 7.086674,
#  'Fossil_Consumption': 79.698299,
#  'Gas_Consumption': 23.084647,
#  'Geo_Consumption': 0.163359,
#  'Hydro_Consumption': 3.589656,
#  'Petro_Consumption': 35.588927,
#  'Solar_Consumption': 0.069134,
#  'Total_Renewable_Consumption': 7.012394,
#  'Total_primary_Cosumption': 93.934511,
#  'Wind_Consumption': 0.03344,
#  'Year': 1996,
#  '_id': ObjectId('5fc69f45b7abff5a7656b783')}
# ------------------------
# {'Bio_Consumption': 3.10522,
#  'Coal_Consumption': 21.445411,
#  'Electric_consumption': 6.596992,
#  'Fossil_Consumption': 80.779682,
#  'Gas_Consumption': 23.222716,
#  'Geo_Consumption': 0.166698,
#  'Hydro_Consumption': 3.640458,
#  'Petro_Consumption': 36.065115,
#  'Solar_Consumption': 0.068166,
#  'Total_Renewable_Consumption': 7.014122,
#  'Total_primary_Cosumption': 94.506999,
#  'Wind_Consumption': 0.033581,
#  'Year': 1997,
#  '_id': ObjectId('5fc69f45b7abff5a7656b784')}
# ------------------------
# {'Bio_Consumption': 2.92749,
#  'Coal_Consumption': 21.655744,
#  'Electric_consumption': 7.067809,
#  'Fossil_Consumption': 81.272862,
#  'Gas_Consumption': 22.830226,
#  'Geo_Consumption': 0.16845,
#  'Hydro_Consumption': 3.297054,
#  'Petro_Consumption': 36.719796,
#  'Solar_Consumption': 0.067449,
#  'Total_Renewable_Consumption': 6.491296,
#  'Total_primary_Cosumption': 94.92019,
#  'Wind_Consumption': 0.030853,
#  'Year': 1998,
#  '_id': ObjectId('5fc69f45b7abff5a7656b785')}
# ------------------------
# {'Bio_Consumption': 2.96329,
#  'Coal_Consumption': 21.622544,
#  'Electric_consumption': 7.610256,
#  'Fossil_Consumption': 82.321598,
#  'Gas_Consumption': 22.909227,
#  'Geo_Consumption': 0.170921,
#  'Hydro_Consumption': 3.267575,
#  'Petro_Consumption': 37.732135,
#  'Solar_Consumption': 0.066066,
#  'Total_Renewable_Consumption': 6.513747,
#  'Total_primary_Cosumption': 96.544524,
#  'Wind_Consumption': 0.045894,
#  'Year': 1999,
#  '_id': ObjectId('5fc69f45b7abff5a7656b786')}
# ------------------------
# {'Bio_Consumption': 3.008227,
#  'Coal_Consumption': 22.579528,
#  'Electric_consumption': 7.862349,
#  'Fossil_Consumption': 84.620442,
#  'Gas_Consumption': 23.823977,
#  'Geo_Consumption': 0.164364,
#  'Hydro_Consumption': 2.811116,
#  'Petro_Consumption': 38.151574,
#  'Solar_Consumption': 0.063469,
#  'Total_Renewable_Consumption': 6.104234,
#  'Total_primary_Cosumption': 98.702224,
#  'Wind_Consumption': 0.057057,
#  'Year': 2000,
#  '_id': ObjectId('5fc69f45b7abff5a7656b787')}
# ------------------------
# {'Bio_Consumption': 2.622356,
#  'Coal_Consumption': 21.914268,
#  'Electric_consumption': 8.028853,
#  'Fossil_Consumption': 82.799758,
#  'Gas_Consumption': 22.772558,
#  'Geo_Consumption': 0.164461,
#  'Hydro_Consumption': 2.241858,
#  'Petro_Consumption': 38.083673,
#  'Solar_Consumption': 0.061674,
#  'Total_Renewable_Consumption': 5.159966,
#  'Total_primary_Cosumption': 96.063734,
#  'Wind_Consumption': 0.069617,
#  'Year': 2001,
#  '_id': ObjectId('5fc69f45b7abff5a7656b788')}
# ------------------------
# {'Bio_Consumption': 2.700621,
#  'Coal_Consumption': 21.903989,
#  'Electric_consumption': 8.145429,
#  'Fossil_Consumption': 83.59225,
#  'Gas_Consumption': 23.510081,
#  'Geo_Consumption': 0.171164,
#  'Hydro_Consumption': 2.689017,
#  'Petro_Consumption': 38.117422,
#  'Solar_Consumption': 0.05998,
#  'Total_Renewable_Consumption': 5.726116,
#  'Total_primary_Cosumption': 97.535391,
#  'Wind_Consumption': 0.105334,
#  'Year': 2002,
#  '_id': ObjectId('5fc69f45b7abff5a7656b789')}
# ------------------------
# {'Bio_Consumption': 2.806471,
#  'Coal_Consumption': 22.320928,
#  'Electric_consumption': 7.959622,
#  'Fossil_Consumption': 83.909087,
#  'Gas_Consumption': 22.830642,
#  'Geo_Consumption': 0.173445,
#  'Hydro_Consumption': 2.792539,
#  'Petro_Consumption': 38.707001,
#  'Solar_Consumption': 0.058432,
#  'Total_Renewable_Consumption': 5.94416,
#  'Total_primary_Cosumption': 97.834773,
#  'Wind_Consumption': 0.113273,
#  'Year': 2003,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78a')}
# ------------------------
# {'Bio_Consumption': 3.008073,
#  'Coal_Consumption': 22.466195,
#  'Electric_consumption': 8.222774,
#  'Fossil_Consumption': 85.666271,
#  'Gas_Consumption': 22.923061,
#  'Geo_Consumption': 0.178147,
#  'Hydro_Consumption': 2.688468,
#  'Petro_Consumption': 40.139253,
#  'Solar_Consumption': 0.058376,
#  'Total_Renewable_Consumption': 6.074726,
#  'Total_primary_Cosumption': 100.002368,
#  'Wind_Consumption': 0.141664,
#  'Year': 2004,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78b')}
# ------------------------
# {'Bio_Consumption': 3.11393,
#  'Coal_Consumption': 22.796543,
#  'Electric_consumption': 8.16081,
#  'Fossil_Consumption': 85.622667,
#  'Gas_Consumption': 22.565364,
#  'Geo_Consumption': 0.180703,
#  'Hydro_Consumption': 2.702942,
#  'Petro_Consumption': 40.216568,
#  'Solar_Consumption': 0.057893,
#  'Total_Renewable_Consumption': 6.233556,
#  'Total_primary_Cosumption': 100.101576,
#  'Wind_Consumption': 0.178088,
#  'Year': 2005,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78c')}
# ------------------------
# {'Bio_Consumption': 3.26214,
#  'Coal_Consumption': 22.44716,
#  'Electric_consumption': 8.214626,
#  'Fossil_Consumption': 84.477197,
#  'Gas_Consumption': 22.238738,
#  'Geo_Consumption': 0.1812,
#  'Hydro_Consumption': 2.869035,
#  'Petro_Consumption': 39.730512,
#  'Solar_Consumption': 0.060755,
#  'Total_Renewable_Consumption': 6.636868,
#  'Total_primary_Cosumption': 99.391541,
#  'Wind_Consumption': 0.263738,
#  'Year': 2006,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78d')}
# ------------------------
# {'Bio_Consumption': 3.484824,
#  'Coal_Consumption': 22.749466,
#  'Electric_consumption': 8.458589,
#  'Fossil_Consumption': 85.805032,
#  'Gas_Consumption': 23.662759,
#  'Geo_Consumption': 0.185774,
#  'Hydro_Consumption': 2.446389,
#  'Petro_Consumption': 39.367615,
#  'Solar_Consumption': 0.065621,
#  'Total_Renewable_Consumption': 6.52311,
#  'Total_primary_Cosumption': 100.893363,
#  'Wind_Consumption': 0.340503,
#  'Year': 2007,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78e')}
# ------------------------
# {'Bio_Consumption': 3.851392,
#  'Coal_Consumption': 22.387437,
#  'Electric_consumption': 8.426491,
#  'Fossil_Consumption': 83.040546,
#  'Gas_Consumption': 23.842953,
#  'Geo_Consumption': 0.192433,
#  'Hydro_Consumption': 2.511108,
#  'Petro_Consumption': 36.769383,
#  'Solar_Consumption': 0.074207,
#  'Total_Renewable_Consumption': 7.174689,
#  'Total_primary_Cosumption': 98.753711,
#  'Wind_Consumption': 0.545548,
#  'Year': 2008,
#  '_id': ObjectId('5fc69f45b7abff5a7656b78f')}
# ------------------------
# {'Bio_Consumption': 3.940009,
#  'Coal_Consumption': 19.691205,
#  'Electric_consumption': 8.35522,
#  'Fossil_Consumption': 77.862484,
#  'Gas_Consumption': 23.41594,
#  'Geo_Consumption': 0.200185,
#  'Hydro_Consumption': 2.668824,
#  'Petro_Consumption': 34.77915,
#  'Solar_Consumption': 0.078178,
#  'Total_Renewable_Consumption': 7.608324,
#  'Total_primary_Cosumption': 93.942216,
#  'Wind_Consumption': 0.721129,
#  'Year': 2009,
#  '_id': ObjectId('5fc69f45b7abff5a7656b790')}
# ------------------------
# {'Bio_Consumption': 4.505882,
#  'Coal_Consumption': 20.833968,
#  'Electric_consumption': 8.434433,
#  'Fossil_Consumption': 80.723061,
#  'Gas_Consumption': 24.574754,
#  'Geo_Consumption': 0.207979,
#  'Hydro_Consumption': 2.538541,
#  'Petro_Consumption': 35.320511,
#  'Solar_Consumption': 0.091282,
#  'Total_Renewable_Consumption': 8.267112,
#  'Total_primary_Cosumption': 97.513239,
#  'Wind_Consumption': 0.923427,
#  'Year': 2010,
#  '_id': ObjectId('5fc69f45b7abff5a7656b791')}
# ------------------------
# {'Bio_Consumption': 4.608932,
#  'Coal_Consumption': 19.657784,
#  'Electric_consumption': 8.268698,
#  'Fossil_Consumption': 79.262601,
#  'Gas_Consumption': 24.954539,
#  'Geo_Consumption': 0.212311,
#  'Hydro_Consumption': 3.102852,
#  'Petro_Consumption': 34.639174,
#  'Solar_Consumption': 0.112429,
#  'Total_Renewable_Consumption': 9.20416,
#  'Total_primary_Cosumption': 96.86256,
#  'Wind_Consumption': 1.167636,
#  'Year': 2011,
#  '_id': ObjectId('5fc69f45b7abff5a7656b792')}
# ------------------------
# {'Bio_Consumption': 4.507805,
#  'Coal_Consumption': 17.378234,
#  'Electric_consumption': 8.061822,
#  'Fossil_Consumption': 77.303882,
#  'Gas_Consumption': 26.088582,
#  'Geo_Consumption': 0.211592,
#  'Hydro_Consumption': 2.628702,
#  'Petro_Consumption': 33.833083,
#  'Solar_Consumption': 0.158961,
#  'Total_Renewable_Consumption': 8.847119,
#  'Total_primary_Cosumption': 94.374079,
#  'Wind_Consumption': 1.340059,
#  'Year': 2012,
#  '_id': ObjectId('5fc69f45b7abff5a7656b793')}
# ------------------------
# {'Bio_Consumption': 4.848354,
#  'Coal_Consumption': 18.038633,
#  'Electric_consumption': 8.244433,
#  'Fossil_Consumption': 79.22427,
#  'Gas_Consumption': 26.805134,
#  'Geo_Consumption': 0.214006,
#  'Hydro_Consumption': 2.562382,
#  'Petro_Consumption': 34.397925,
#  'Solar_Consumption': 0.224524,
#  'Total_Renewable_Consumption': 9.450625,
#  'Total_primary_Cosumption': 97.116801,
#  'Wind_Consumption': 1.601359,
#  'Year': 2013,
#  '_id': ObjectId('5fc69f45b7abff5a7656b794')}
# ------------------------
# {'Bio_Consumption': 4.994208,
#  'Coal_Consumption': 17.997632,
#  'Electric_consumption': 8.337559,
#  'Fossil_Consumption': 80.016732,
#  'Gas_Consumption': 27.382833,
#  'Geo_Consumption': 0.21449,
#  'Hydro_Consumption': 2.466577,
#  'Petro_Consumption': 34.657827,
#  'Solar_Consumption': 0.337543,
#  'Total_Renewable_Consumption': 9.74036,
#  'Total_primary_Cosumption': 98.27621,
#  'Wind_Consumption': 1.727542,
#  'Year': 2014,
#  '_id': ObjectId('5fc69f45b7abff5a7656b795')}
# ------------------------
# {'Bio_Consumption': 4.983358,
#  'Coal_Consumption': 15.54887,
#  'Electric_consumption': 8.336886,
#  'Fossil_Consumption': 79.090311,
#  'Gas_Consumption': 28.191095,
#  'Geo_Consumption': 0.211836,
#  'Hydro_Consumption': 2.321177,
#  'Petro_Consumption': 35.368127,
#  'Solar_Consumption': 0.426867,
#  'Total_Renewable_Consumption': 9.720544,
#  'Total_primary_Cosumption': 97.375221,
#  'Wind_Consumption': 1.777306,
#  'Year': 2015,
#  '_id': ObjectId('5fc69f45b7abff5a7656b796')}
# ------------------------
# {'Bio_Consumption': 5.014521,
#  'Coal_Consumption': 14.225905,
#  'Electric_consumption': 8.426753,
#  'Fossil_Consumption': 78.31902,
#  'Gas_Consumption': 28.400352,
#  'Geo_Consumption': 0.209604,
#  'Hydro_Consumption': 2.472442,
#  'Petro_Consumption': 35.711903,
#  'Solar_Consumption': 0.570368,
#  'Total_Renewable_Consumption': 10.36253,
#  'Total_primary_Cosumption': 97.335208,
#  'Wind_Consumption': 2.095595,
#  'Year': 2016,
#  '_id': ObjectId('5fc69f45b7abff5a7656b797')}
# ------------------------
# {'Bio_Consumption': 4.97934,
#  'Coal_Consumption': 13.837465,
#  'Electric_consumption': 8.418968,
#  'Fossil_Consumption': 77.907116,
#  'Gas_Consumption': 28.055093,
#  'Geo_Consumption': 0.210233,
#  'Hydro_Consumption': 2.766967,
#  'Petro_Consumption': 36.043156,
#  'Solar_Consumption': 0.777084,
#  'Total_Renewable_Consumption': 11.076515,
#  'Total_primary_Cosumption': 97.594743,
#  'Wind_Consumption': 2.342891,
#  'Year': 2017,
#  '_id': ObjectId('5fc69f45b7abff5a7656b798')}
# ------------------------
# {'Bio_Consumption': 5.0311,
#  'Coal_Consumption': 13.251532,
#  'Electric_consumption': 8.438068,
#  'Fossil_Consumption': 81.271119,
#  'Gas_Consumption': 31.153422,
#  'Geo_Consumption': 0.208865,
#  'Hydro_Consumption': 2.663138,
#  'Petro_Consumption': 36.89182,
#  'Solar_Consumption': 0.915513,
#  'Total_Renewable_Consumption': 11.30098,
#  'Total_primary_Cosumption': 101.161852,
#  'Wind_Consumption': 2.482364,
#  'Year': 2018,
#  '_id': ObjectId('5fc69f45b7abff5a7656b799')}
# ------------------------
# {'Bio_Consumption': 4.923807,
#  'Coal_Consumption': 11.315515,
#  'Electric_consumption': 8.451852,
#  'Fossil_Consumption': 80.356572,
#  'Gas_Consumption': 32.195798,
#  'Geo_Consumption': 0.201269,
#  'Hydro_Consumption': 2.563228,
#  'Petro_Consumption': 36.866381,
#  'Solar_Consumption': 1.018013,
#  'Total_Renewable_Consumption': 11.332162,
#  'Total_primary_Cosumption': 100.273806,
#  'Wind_Consumption': 2.625846,
#  'Year': 2019,
#  '_id': ObjectId('5fc69f45b7abff5a7656b79a')}
# ------------------------

# %%
# Energy production collection created in mongo
#Declare the collection
col_engprod=db['energyproduction']

energy_prod=energy_prod.to_dict('records')
col_engprod.insert_many(energy_prod)

# %%
for row in db.energyproduction.find():
    pprint(row)
    print("------------------------")
# Out:
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1424.722,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1549.262,
#  'Total_Biomass_Prod': 1549.262,
#  'Total_Energy_Consumption': 31967.774999999998,
#  'Total_Renewable_Consumption': 2973.984,
#  'Total_Renewable_Production': 2973.984,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1549.262,
#  'Wood_production': 1549.262,
#  'Year': 1949,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e3')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1415.411,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1562.307,
#  'Total_Biomass_Prod': 1562.307,
#  'Total_Energy_Consumption': 34598.567,
#  'Total_Renewable_Consumption': 2977.718,
#  'Total_Renewable_Production': 2977.718,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1562.307,
#  'Wood_production': 1562.307,
#  'Year': 1950,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e4')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1423.795,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1534.669,
#  'Total_Biomass_Prod': 1534.669,
#  'Total_Energy_Consumption': 36953.661,
#  'Total_Renewable_Consumption': 2958.464,
#  'Total_Renewable_Production': 2958.464,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1534.669,
#  'Wood_production': 1534.669,
#  'Year': 1951,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e5')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1465.812,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1474.369,
#  'Total_Biomass_Prod': 1474.369,
#  'Total_Energy_Consumption': 36726.037,
#  'Total_Renewable_Consumption': 2940.181,
#  'Total_Renewable_Production': 2940.181,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1474.369,
#  'Wood_production': 1474.369,
#  'Year': 1952,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e6')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1412.859,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1418.601,
#  'Total_Biomass_Prod': 1418.601,
#  'Total_Energy_Consumption': 37640.598,
#  'Total_Renewable_Consumption': 2831.46,
#  'Total_Renewable_Production': 2831.46,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1418.601,
#  'Wood_production': 1418.601,
#  'Year': 1953,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e7')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1359.772,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1394.327,
#  'Total_Biomass_Prod': 1394.327,
#  'Total_Energy_Consumption': 36613.54,
#  'Total_Renewable_Consumption': 2754.099,
#  'Total_Renewable_Production': 2754.099,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1394.327,
#  'Wood_production': 1394.327,
#  'Year': 1954,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e8')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1359.844,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1424.143,
#  'Total_Biomass_Prod': 1424.143,
#  'Total_Energy_Consumption': 40178.285,
#  'Total_Renewable_Consumption': 2783.987,
#  'Total_Renewable_Production': 2783.987,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1424.143,
#  'Wood_production': 1424.143,
#  'Year': 1955,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7e9')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1434.711,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1415.871,
#  'Total_Biomass_Prod': 1415.871,
#  'Total_Energy_Consumption': 41721.757,
#  'Total_Renewable_Consumption': 2850.582,
#  'Total_Renewable_Production': 2850.582,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1415.871,
#  'Wood_production': 1415.871,
#  'Year': 1956,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ea')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1515.613,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1333.581,
#  'Total_Biomass_Prod': 1333.581,
#  'Total_Energy_Consumption': 41753.909,
#  'Total_Renewable_Consumption': 2849.194,
#  'Total_Renewable_Production': 2849.194,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1333.581,
#  'Wood_production': 1333.581,
#  'Year': 1957,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7eb')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1591.967,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1323.123,
#  'Total_Biomass_Prod': 1323.123,
#  'Total_Energy_Consumption': 41609.28,
#  'Total_Renewable_Consumption': 2915.09,
#  'Total_Renewable_Production': 2915.09,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1323.123,
#  'Wood_production': 1323.123,
#  'Year': 1958,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ec')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.0,
#  'Hydro_consumption': 1548.465,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1352.874,
#  'Total_Biomass_Prod': 1352.874,
#  'Total_Energy_Consumption': 43422.965,
#  'Total_Renewable_Consumption': 2901.339,
#  'Total_Renewable_Production': 2901.339,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1352.874,
#  'Wood_production': 1352.874,
#  'Year': 1959,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ed')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 0.359,
#  'Hydro_consumption': 1607.975,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1319.87,
#  'Total_Biomass_Prod': 1319.87,
#  'Total_Energy_Consumption': 45040.731999999996,
#  'Total_Renewable_Consumption': 2928.204,
#  'Total_Renewable_Production': 2928.204,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1319.87,
#  'Wood_production': 1319.87,
#  'Year': 1960,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ee')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 1.001,
#  'Hydro_consumption': 1656.463,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1294.762,
#  'Total_Biomass_Prod': 1294.762,
#  'Total_Energy_Consumption': 45690.782,
#  'Total_Renewable_Consumption': 2952.226,
#  'Total_Renewable_Production': 2952.226,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1294.762,
#  'Wood_production': 1294.762,
#  'Year': 1961,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ef')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 1.061,
#  'Hydro_consumption': 1816.141,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1300.242,
#  'Total_Biomass_Prod': 1300.242,
#  'Total_Energy_Consumption': 47775.047,
#  'Total_Renewable_Consumption': 3117.444,
#  'Total_Renewable_Production': 3117.444,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1300.242,
#  'Wood_production': 1300.242,
#  'Year': 1962,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f0')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 1.76,
#  'Hydro_consumption': 1771.355,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1323.316,
#  'Total_Biomass_Prod': 1323.316,
#  'Total_Energy_Consumption': 49588.632,
#  'Total_Renewable_Consumption': 3096.431,
#  'Total_Renewable_Production': 3096.431,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1323.316,
#  'Wood_production': 1323.316,
#  'Year': 1963,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f1')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 2.132,
#  'Hydro_consumption': 1886.314,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1336.802,
#  'Total_Biomass_Prod': 1336.802,
#  'Total_Energy_Consumption': 51755.425,
#  'Total_Renewable_Consumption': 3225.248,
#  'Total_Renewable_Production': 3225.248,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1336.802,
#  'Wood_production': 1336.802,
#  'Year': 1964,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f2')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 1.978,
#  'Hydro_consumption': 2059.077,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1334.761,
#  'Total_Biomass_Prod': 1334.761,
#  'Total_Energy_Consumption': 53953.221999999994,
#  'Total_Renewable_Consumption': 3395.816,
#  'Total_Renewable_Production': 3395.816,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1334.761,
#  'Wood_production': 1334.761,
#  'Year': 1965,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f3')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 1.958,
#  'Hydro_consumption': 2061.519,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1368.985,
#  'Total_Biomass_Prod': 1368.985,
#  'Total_Energy_Consumption': 56949.167,
#  'Total_Renewable_Consumption': 3432.462,
#  'Total_Renewable_Production': 3432.462,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1368.985,
#  'Wood_production': 1368.985,
#  'Year': 1966,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f4')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 3.3,
#  'Hydro_consumption': 2346.664,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1340.249,
#  'Total_Biomass_Prod': 1340.249,
#  'Total_Energy_Consumption': 58894.82,
#  'Total_Renewable_Consumption': 3690.213,
#  'Total_Renewable_Production': 3690.213,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1340.249,
#  'Wood_production': 1340.249,
#  'Year': 1967,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f5')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 4.532,
#  'Hydro_consumption': 2348.629,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1419.495,
#  'Total_Biomass_Prod': 1419.495,
#  'Total_Energy_Consumption': 62401.479999999996,
#  'Total_Renewable_Consumption': 3772.656,
#  'Total_Renewable_Production': 3772.656,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1419.495,
#  'Wood_production': 1419.495,
#  'Year': 1968,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f6')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 6.422,
#  'Hydro_consumption': 2647.983,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1440.487,
#  'Total_Biomass_Prod': 1440.487,
#  'Total_Energy_Consumption': 65596.259,
#  'Total_Renewable_Consumption': 4094.892,
#  'Total_Renewable_Production': 4094.892,
#  'WasteEnergy_Consumption': 0.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1440.487,
#  'Wood_production': 1440.487,
#  'Year': 1969,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f7')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 5.511,
#  'Hydro_consumption': 2633.547,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1430.962,
#  'Total_Biomass_Prod': 1430.962,
#  'Total_Energy_Consumption': 67816.828,
#  'Total_Renewable_Consumption': 4070.021,
#  'Total_Renewable_Production': 4070.021,
#  'WasteEnergy_Consumption': 2.313,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1428.649,
#  'Wood_production': 1428.649,
#  'Year': 1970,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f8')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 5.739,
#  'Hydro_consumption': 2824.151,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1432.323,
#  'Total_Biomass_Prod': 1432.323,
#  'Total_Energy_Consumption': 69260.27100000001,
#  'Total_Renewable_Consumption': 4262.213,
#  'Total_Renewable_Production': 4262.213,
#  'WasteEnergy_Consumption': 2.094,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1430.229,
#  'Wood_production': 1430.229,
#  'Year': 1971,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7f9')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 15.079,
#  'Hydro_consumption': 2863.865,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1503.065,
#  'Total_Biomass_Prod': 1503.065,
#  'Total_Energy_Consumption': 72660.03600000001,
#  'Total_Renewable_Consumption': 4382.009,
#  'Total_Renewable_Production': 4382.009,
#  'WasteEnergy_Consumption': 2.073,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1500.992,
#  'Wood_production': 1500.992,
#  'Year': 1972,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7fa')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 20.422,
#  'Hydro_consumption': 2861.448,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1529.068,
#  'Total_Biomass_Prod': 1529.068,
#  'Total_Energy_Consumption': 75652.28,
#  'Total_Renewable_Consumption': 4410.938,
#  'Total_Renewable_Production': 4410.938,
#  'WasteEnergy_Consumption': 2.056,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1527.012,
#  'Wood_production': 1527.012,
#  'Year': 1973,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7fb')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 25.61,
#  'Hydro_consumption': 3176.58,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1539.662,
#  'Total_Biomass_Prod': 1539.662,
#  'Total_Energy_Consumption': 73929.322,
#  'Total_Renewable_Consumption': 4741.852,
#  'Total_Renewable_Production': 4741.852,
#  'WasteEnergy_Consumption': 1.902,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1537.76,
#  'Wood_production': 1537.76,
#  'Year': 1974,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7fc')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 33.78,
#  'Hydro_consumption': 3154.607,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1498.734,
#  'Total_Biomass_Prod': 1498.734,
#  'Total_Energy_Consumption': 71931.011,
#  'Total_Renewable_Consumption': 4687.12,
#  'Total_Renewable_Production': 4687.12,
#  'WasteEnergy_Consumption': 1.806,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1496.928,
#  'Wood_production': 1496.928,
#  'Year': 1975,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7fd')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 37.513,
#  'Hydro_consumption': 2976.265,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1713.373,
#  'Total_Biomass_Prod': 1713.373,
#  'Total_Energy_Consumption': 75939.02900000001,
#  'Total_Renewable_Consumption': 4727.151,
#  'Total_Renewable_Production': 4727.151,
#  'WasteEnergy_Consumption': 1.889,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1711.484,
#  'Wood_production': 1711.484,
#  'Year': 1976,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7fe')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 37.382,
#  'Hydro_consumption': 2333.252,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 1838.332,
#  'Total_Biomass_Prod': 1838.332,
#  'Total_Energy_Consumption': 77919.991,
#  'Total_Renewable_Consumption': 4208.966,
#  'Total_Renewable_Production': 4208.966,
#  'WasteEnergy_Consumption': 1.808,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 1836.524,
#  'Wood_production': 1836.524,
#  'Year': 1977,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b7ff')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 30.851,
#  'Hydro_consumption': 2936.983,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2037.605,
#  'Total_Biomass_Prod': 2037.605,
#  'Total_Energy_Consumption': 79906.703,
#  'Total_Renewable_Consumption': 5005.44,
#  'Total_Renewable_Production': 5005.44,
#  'WasteEnergy_Consumption': 1.455,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 2036.15,
#  'Wood_production': 2036.15,
#  'Year': 1978,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b800')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 40.262,
#  'Hydro_consumption': 2930.686,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2151.906,
#  'Total_Biomass_Prod': 2151.906,
#  'Total_Energy_Consumption': 80811.788,
#  'Total_Renewable_Consumption': 5122.854,
#  'Total_Renewable_Production': 5122.854,
#  'WasteEnergy_Consumption': 2.052,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 2149.854,
#  'Wood_production': 2149.854,
#  'Year': 1979,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b801')}
# ------------------------
# {'Biofuel_Production': 0.0,
#  'Biofuel_consumption': 0.0,
#  'Geo_Consumption': 52.699,
#  'Hydro_consumption': 2900.144,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2475.5,
#  'Total_Biomass_Prod': 2475.5,
#  'Total_Energy_Consumption': 78021.113,
#  'Total_Renewable_Consumption': 5428.342,
#  'Total_Renewable_Production': 5428.342,
#  'WasteEnergy_Consumption': 1.639,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 2473.861,
#  'Wood_production': 2473.861,
#  'Year': 1980,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b802')}
# ------------------------
# {'Biofuel_Production': 12.72,
#  'Biofuel_consumption': 12.72,
#  'Geo_Consumption': 59.437,
#  'Hydro_consumption': 2757.968,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2596.283,
#  'Total_Biomass_Prod': 2596.283,
#  'Total_Energy_Consumption': 76057.187,
#  'Total_Renewable_Consumption': 5413.688,
#  'Total_Renewable_Production': 5413.688,
#  'WasteEnergy_Consumption': 88.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 2495.563,
#  'Wood_production': 2495.563,
#  'Year': 1981,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b803')}
# ------------------------
# {'Biofuel_Production': 34.404,
#  'Biofuel_consumption': 34.404,
#  'Geo_Consumption': 50.627,
#  'Hydro_consumption': 3265.558,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2663.452,
#  'Total_Biomass_Prod': 2663.452,
#  'Total_Energy_Consumption': 73046.189,
#  'Total_Renewable_Consumption': 5979.637,
#  'Total_Renewable_Production': 5979.637,
#  'WasteEnergy_Consumption': 119.0,
#  'Wind_Consumption': 0.0,
#  'Wood_Consumption': 2510.048,
#  'Wood_production': 2510.048,
#  'Year': 1982,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b804')}
# ------------------------
# {'Biofuel_Production': 63.143,
#  'Biofuel_consumption': 63.143,
#  'Geo_Consumption': 63.91,
#  'Hydro_consumption': 3527.26,
#  'Solar_Consumption': 0.0,
#  'Total_Biomass_Consumption': 2904.414,
#  'Total_Biomass_Prod': 2904.414,
#  'Total_Energy_Consumption': 72915.394,
#  'Total_Renewable_Consumption': 6495.612,
#  'Total_Renewable_Production': 6495.612,
#  'WasteEnergy_Consumption': 157.0,
#  'Wind_Consumption': 0.028,
#  'Wood_Consumption': 2684.271,
#  'Wood_production': 2684.271,
#  'Year': 1983,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b805')}
# ------------------------
# {'Biofuel_Production': 77.302,
#  'Biofuel_consumption': 77.302,
#  'Geo_Consumption': 80.811,
#  'Hydro_consumption': 3385.811,
#  'Solar_Consumption': 0.055,
#  'Total_Biomass_Consumption': 2971.12,
#  'Total_Biomass_Prod': 2971.12,
#  'Total_Energy_Consumption': 76570.697,
#  'Total_Renewable_Consumption': 6437.864,
#  'Total_Renewable_Production': 6437.864,
#  'WasteEnergy_Consumption': 208.0,
#  'Wind_Consumption': 0.068,
#  'Wood_Consumption': 2685.817,
#  'Wood_production': 2685.817,
#  'Year': 1984,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b806')}
# ------------------------
# {'Biofuel_Production': 93.151,
#  'Biofuel_consumption': 93.151,
#  'Geo_Consumption': 97.421,
#  'Hydro_consumption': 2970.192,
#  'Solar_Consumption': 0.111,
#  'Total_Biomass_Consumption': 3016.233,
#  'Total_Biomass_Prod': 3016.233,
#  'Total_Energy_Consumption': 76334.13500000001,
#  'Total_Renewable_Consumption': 6084.017,
#  'Total_Renewable_Production': 6084.017,
#  'WasteEnergy_Consumption': 236.317,
#  'Wind_Consumption': 0.06,
#  'Wood_Consumption': 2686.765,
#  'Wood_production': 2686.765,
#  'Year': 1985,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b807')}
# ------------------------
# {'Biofuel_Production': 107.099,
#  'Biofuel_consumption': 107.099,
#  'Geo_Consumption': 107.677,
#  'Hydro_consumption': 3071.179,
#  'Solar_Consumption': 0.147,
#  'Total_Biomass_Consumption': 2932.095,
#  'Total_Biomass_Prod': 2932.095,
#  'Total_Energy_Consumption': 76598.888,
#  'Total_Renewable_Consumption': 6111.14,
#  'Total_Renewable_Production': 6111.14,
#  'WasteEnergy_Consumption': 262.861,
#  'Wind_Consumption': 0.044,
#  'Wood_Consumption': 2562.134,
#  'Wood_production': 2562.134,
#  'Year': 1986,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b808')}
# ------------------------
# {'Biofuel_Production': 122.725,
#  'Biofuel_consumption': 122.725,
#  'Geo_Consumption': 112.27,
#  'Hydro_consumption': 2634.508,
#  'Solar_Consumption': 0.109,
#  'Total_Biomass_Consumption': 2874.884,
#  'Total_Biomass_Prod': 2874.884,
#  'Total_Energy_Consumption': 79008.203,
#  'Total_Renewable_Consumption': 5621.807,
#  'Total_Renewable_Production': 5621.807,
#  'WasteEnergy_Consumption': 289.0,
#  'Wind_Consumption': 0.037,
#  'Wood_Consumption': 2463.159,
#  'Wood_production': 2463.159,
#  'Year': 1987,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b809')}
# ------------------------
# {'Biofuel_Production': 124.058,
#  'Biofuel_consumption': 124.058,
#  'Geo_Consumption': 106.338,
#  'Hydro_consumption': 2334.265,
#  'Solar_Consumption': 0.094,
#  'Total_Biomass_Consumption': 3016.049,
#  'Total_Biomass_Prod': 3016.049,
#  'Total_Energy_Consumption': 82659.16900000001,
#  'Total_Renewable_Consumption': 5456.754,
#  'Total_Renewable_Production': 5456.754,
#  'WasteEnergy_Consumption': 315.328,
#  'Wind_Consumption': 0.009,
#  'Wood_Consumption': 2576.663,
#  'Wood_production': 2576.663,
#  'Year': 1988,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80a')}
# ------------------------
# {'Biofuel_Production': 125.378,
#  'Biofuel_consumption': 125.378,
#  'Geo_Consumption': 161.539,
#  'Hydro_consumption': 2837.263,
#  'Solar_Consumption': 54.466,
#  'Total_Biomass_Consumption': 3159.357,
#  'Total_Biomass_Prod': 3159.357,
#  'Total_Energy_Consumption': 84739.993,
#  'Total_Renewable_Consumption': 6234.658,
#  'Total_Renewable_Production': 6234.658,
#  'WasteEnergy_Consumption': 354.356,
#  'Wind_Consumption': 22.033,
#  'Wood_Consumption': 2679.623,
#  'Wood_production': 2679.623,
#  'Year': 1989,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80b')}
# ------------------------
# {'Biofuel_Production': 110.867,
#  'Biofuel_consumption': 110.867,
#  'Geo_Consumption': 170.747,
#  'Hydro_consumption': 3046.391,
#  'Solar_Consumption': 58.768,
#  'Total_Biomass_Consumption': 2735.112,
#  'Total_Biomass_Prod': 2735.112,
#  'Total_Energy_Consumption': 84432.86,
#  'Total_Renewable_Consumption': 6040.024,
#  'Total_Renewable_Production': 6040.024,
#  'WasteEnergy_Consumption': 408.079,
#  'Wind_Consumption': 29.007,
#  'Wood_Consumption': 2216.166,
#  'Wood_production': 2216.166,
#  'Year': 1990,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80c')}
# ------------------------
# {'Biofuel_Production': 128.0,
#  'Biofuel_consumption': 128.0,
#  'Geo_Consumption': 177.626,
#  'Hydro_consumption': 3015.943,
#  'Solar_Consumption': 61.623,
#  'Total_Biomass_Consumption': 2781.797,
#  'Total_Biomass_Prod': 2781.797,
#  'Total_Energy_Consumption': 84380.3,
#  'Total_Renewable_Consumption': 6067.785,
#  'Total_Renewable_Production': 6067.785,
#  'WasteEnergy_Consumption': 439.715,
#  'Wind_Consumption': 30.796,
#  'Wood_Consumption': 2214.082,
#  'Wood_production': 2214.082,
#  'Year': 1991,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80d')}
# ------------------------
# {'Biofuel_Production': 145.005,
#  'Biofuel_consumption': 145.005,
#  'Geo_Consumption': 178.699,
#  'Hydro_consumption': 2617.436,
#  'Solar_Consumption': 62.88,
#  'Total_Biomass_Consumption': 2931.678,
#  'Total_Biomass_Prod': 2931.678,
#  'Total_Energy_Consumption': 85724.885,
#  'Total_Renewable_Consumption': 5820.556,
#  'Total_Renewable_Production': 5820.556,
#  'WasteEnergy_Consumption': 473.202,
#  'Wind_Consumption': 29.863,
#  'Wood_Consumption': 2313.471,
#  'Wood_production': 2313.471,
#  'Year': 1992,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80e')}
# ------------------------
# {'Biofuel_Production': 169.336,
#  'Biofuel_consumption': 169.062,
#  'Geo_Consumption': 185.673,
#  'Hydro_consumption': 2891.613,
#  'Solar_Consumption': 65.19,
#  'Total_Biomass_Consumption': 2908.172,
#  'Total_Biomass_Prod': 2908.446,
#  'Total_Energy_Consumption': 87265.888,
#  'Total_Renewable_Consumption': 6081.635,
#  'Total_Renewable_Production': 6081.909,
#  'WasteEnergy_Consumption': 479.336,
#  'Wind_Consumption': 30.987,
#  'Wood_Consumption': 2259.774,
#  'Wood_production': 2259.774,
#  'Year': 1993,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b80f')}
# ------------------------
# {'Biofuel_Production': 188.391,
#  'Biofuel_consumption': 188.391,
#  'Geo_Consumption': 173.464,
#  'Hydro_consumption': 2683.457,
#  'Solar_Consumption': 67.126,
#  'Total_Biomass_Consumption': 3027.534,
#  'Total_Biomass_Prod': 3027.534,
#  'Total_Energy_Consumption': 88983.234,
#  'Total_Renewable_Consumption': 5987.142,
#  'Total_Renewable_Production': 5987.142,
#  'WasteEnergy_Consumption': 515.323,
#  'Wind_Consumption': 35.56,
#  'Wood_Consumption': 2323.82,
#  'Wood_production': 2323.82,
#  'Year': 1994,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b810')}
# ------------------------
# {'Biofuel_Production': 197.737,
#  'Biofuel_consumption': 199.797,
#  'Geo_Consumption': 152.057,
#  'Hydro_consumption': 3205.307,
#  'Solar_Consumption': 68.233,
#  'Total_Biomass_Consumption': 3101.142,
#  'Total_Biomass_Prod': 3099.082,
#  'Total_Energy_Consumption': 90930.70400000001,
#  'Total_Renewable_Consumption': 6559.369,
#  'Total_Renewable_Production': 6557.308,
#  'WasteEnergy_Consumption': 531.476,
#  'Wind_Consumption': 32.63,
#  'Wood_Consumption': 2369.869,
#  'Wood_production': 2369.869,
#  'Year': 1995,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b811')}
# ------------------------
# {'Biofuel_Production': 141.284,
#  'Biofuel_consumption': 142.789,
#  'Geo_Consumption': 163.359,
#  'Hydro_consumption': 3589.656,
#  'Solar_Consumption': 69.134,
#  'Total_Biomass_Consumption': 3156.806,
#  'Total_Biomass_Prod': 3155.301,
#  'Total_Energy_Consumption': 93934.511,
#  'Total_Renewable_Consumption': 7012.394,
#  'Total_Renewable_Production': 7010.889,
#  'WasteEnergy_Consumption': 576.99,
#  'Wind_Consumption': 33.44,
#  'Wood_Consumption': 2437.027,
#  'Wood_production': 2437.027,
#  'Year': 1996,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b812')}
# ------------------------
# {'Biofuel_Production': 186.315,
#  'Biofuel_consumption': 183.627,
#  'Geo_Consumption': 166.698,
#  'Hydro_consumption': 3640.458,
#  'Solar_Consumption': 68.166,
#  'Total_Biomass_Consumption': 3105.22,
#  'Total_Biomass_Prod': 3107.908,
#  'Total_Energy_Consumption': 94506.999,
#  'Total_Renewable_Consumption': 7014.122,
#  'Total_Renewable_Production': 7016.81,
#  'WasteEnergy_Consumption': 550.602,
#  'Wind_Consumption': 33.581,
#  'Wood_Consumption': 2370.991,
#  'Wood_production': 2370.991,
#  'Year': 1997,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b813')}
# ------------------------
# {'Biofuel_Production': 202.474,
#  'Biofuel_consumption': 201.034,
#  'Geo_Consumption': 168.45,
#  'Hydro_consumption': 3297.054,
#  'Solar_Consumption': 67.449,
#  'Total_Biomass_Consumption': 2927.49,
#  'Total_Biomass_Prod': 2928.93,
#  'Total_Energy_Consumption': 94920.19,
#  'Total_Renewable_Consumption': 6491.296,
#  'Total_Renewable_Production': 6492.735,
#  'WasteEnergy_Consumption': 542.295,
#  'Wind_Consumption': 30.853,
#  'Wood_Consumption': 2184.161,
#  'Wood_production': 2184.161,
#  'Year': 1998,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b814')}
# ------------------------
# {'Biofuel_Production': 210.809,
#  'Biofuel_consumption': 208.967,
#  'Geo_Consumption': 170.921,
#  'Hydro_consumption': 3267.575,
#  'Solar_Consumption': 66.066,
#  'Total_Biomass_Consumption': 2963.29,
#  'Total_Biomass_Prod': 2965.132,
#  'Total_Energy_Consumption': 96544.52399999999,
#  'Total_Renewable_Consumption': 6513.747,
#  'Total_Renewable_Production': 6515.588,
#  'WasteEnergy_Consumption': 540.156,
#  'Wind_Consumption': 45.894,
#  'Wood_Consumption': 2214.167,
#  'Wood_production': 2214.167,
#  'Year': 1999,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b815')}
# ------------------------
# {'Biofuel_Production': 233.146,
#  'Biofuel_consumption': 235.712,
#  'Geo_Consumption': 164.364,
#  'Hydro_consumption': 2811.116,
#  'Solar_Consumption': 63.469,
#  'Total_Biomass_Consumption': 3008.227,
#  'Total_Biomass_Prod': 3005.661,
#  'Total_Energy_Consumption': 98702.224,
#  'Total_Renewable_Consumption': 6104.234,
#  'Total_Renewable_Production': 6101.667,
#  'WasteEnergy_Consumption': 510.8,
#  'Wind_Consumption': 57.057,
#  'Wood_Consumption': 2261.715,
#  'Wood_production': 2261.715,
#  'Year': 2000,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b816')}
# ------------------------
# {'Biofuel_Production': 254.453,
#  'Biofuel_consumption': 252.647,
#  'Geo_Consumption': 164.461,
#  'Hydro_consumption': 2241.858,
#  'Solar_Consumption': 61.674,
#  'Total_Biomass_Consumption': 2622.356,
#  'Total_Biomass_Prod': 2624.162,
#  'Total_Energy_Consumption': 96063.734,
#  'Total_Renewable_Consumption': 5159.966,
#  'Total_Renewable_Production': 5161.772,
#  'WasteEnergy_Consumption': 363.875,
#  'Wind_Consumption': 69.617,
#  'Wood_Consumption': 2005.834,
#  'Wood_production': 2005.834,
#  'Year': 2001,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b817')}
# ------------------------
# {'Biofuel_Production': 308.118,
#  'Biofuel_consumption': 303.333,
#  'Geo_Consumption': 171.164,
#  'Hydro_consumption': 2689.017,
#  'Solar_Consumption': 59.98,
#  'Total_Biomass_Consumption': 2700.621,
#  'Total_Biomass_Prod': 2705.406,
#  'Total_Energy_Consumption': 97535.391,
#  'Total_Renewable_Consumption': 5726.116,
#  'Total_Renewable_Production': 5730.902,
#  'WasteEnergy_Consumption': 402.004,
#  'Wind_Consumption': 105.334,
#  'Wood_Consumption': 1995.284,
#  'Wood_production': 1995.284,
#  'Year': 2002,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b818')}
# ------------------------
# {'Biofuel_Production': 401.394,
#  'Biofuel_consumption': 403.087,
#  'Geo_Consumption': 173.445,
#  'Hydro_consumption': 2792.539,
#  'Solar_Consumption': 58.432,
#  'Total_Biomass_Consumption': 2806.471,
#  'Total_Biomass_Prod': 2804.778,
#  'Total_Energy_Consumption': 97834.773,
#  'Total_Renewable_Consumption': 5944.16,
#  'Total_Renewable_Production': 5942.467,
#  'WasteEnergy_Consumption': 401.347,
#  'Wind_Consumption': 113.273,
#  'Wood_Consumption': 2002.037,
#  'Wood_production': 2002.037,
#  'Year': 2003,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b819')}
# ------------------------
# {'Biofuel_Production': 485.722,
#  'Biofuel_consumption': 497.777,
#  'Geo_Consumption': 178.147,
#  'Hydro_consumption': 2688.468,
#  'Solar_Consumption': 58.376,
#  'Total_Biomass_Consumption': 3008.073,
#  'Total_Biomass_Prod': 2996.017,
#  'Total_Energy_Consumption': 100002.368,
#  'Total_Renewable_Consumption': 6074.726,
#  'Total_Renewable_Production': 6062.671,
#  'WasteEnergy_Consumption': 389.043,
#  'Wind_Consumption': 141.664,
#  'Wood_Consumption': 2121.252,
#  'Wood_production': 2121.252,
#  'Year': 2004,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81a')}
# ------------------------
# {'Biofuel_Production': 561.27,
#  'Biofuel_consumption': 574.014,
#  'Geo_Consumption': 180.703,
#  'Hydro_consumption': 2702.942,
#  'Solar_Consumption': 57.893,
#  'Total_Biomass_Consumption': 3113.93,
#  'Total_Biomass_Prod': 3101.186,
#  'Total_Energy_Consumption': 100101.576,
#  'Total_Renewable_Consumption': 6233.556,
#  'Total_Renewable_Production': 6220.812,
#  'WasteEnergy_Consumption': 403.219,
#  'Wind_Consumption': 178.088,
#  'Wood_Consumption': 2136.697,
#  'Wood_production': 2136.697,
#  'Year': 2005,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81b')}
# ------------------------
# {'Biofuel_Production': 715.635,
#  'Biofuel_consumption': 766.26,
#  'Geo_Consumption': 181.2,
#  'Hydro_consumption': 2869.035,
#  'Solar_Consumption': 60.755,
#  'Total_Biomass_Consumption': 3262.14,
#  'Total_Biomass_Prod': 3211.515,
#  'Total_Energy_Consumption': 99391.541,
#  'Total_Renewable_Consumption': 6636.868,
#  'Total_Renewable_Production': 6586.243,
#  'WasteEnergy_Consumption': 396.561,
#  'Wind_Consumption': 263.738,
#  'Wood_Consumption': 2099.319,
#  'Wood_production': 2099.319,
#  'Year': 2006,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81c')}
# ------------------------
# {'Biofuel_Production': 970.07,
#  'Biofuel_consumption': 982.814,
#  'Geo_Consumption': 185.774,
#  'Hydro_consumption': 2446.389,
#  'Solar_Consumption': 65.621,
#  'Total_Biomass_Consumption': 3484.824,
#  'Total_Biomass_Prod': 3472.08,
#  'Total_Energy_Consumption': 100893.363,
#  'Total_Renewable_Consumption': 6523.11,
#  'Total_Renewable_Production': 6510.367,
#  'WasteEnergy_Consumption': 413.235,
#  'Wind_Consumption': 340.503,
#  'Wood_Consumption': 2088.775,
#  'Wood_production': 2088.775,
#  'Year': 2007,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81d')}
# ------------------------
# {'Biofuel_Production': 1374.001,
#  'Biofuel_consumption': 1357.144,
#  'Geo_Consumption': 192.433,
#  'Hydro_consumption': 2511.108,
#  'Solar_Consumption': 74.207,
#  'Total_Biomass_Consumption': 3851.392,
#  'Total_Biomass_Prod': 3868.25,
#  'Total_Energy_Consumption': 98753.711,
#  'Total_Renewable_Consumption': 7174.689,
#  'Total_Renewable_Production': 7191.546,
#  'WasteEnergy_Consumption': 435.263,
#  'Wind_Consumption': 545.548,
#  'Wood_Consumption': 2058.985,
#  'Wood_production': 2058.985,
#  'Year': 2008,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81e')}
# ------------------------
# {'Biofuel_Production': 1569.92,
#  'Biofuel_consumption': 1553.312,
#  'Geo_Consumption': 200.185,
#  'Hydro_consumption': 2668.824,
#  'Solar_Consumption': 78.178,
#  'Total_Biomass_Consumption': 3940.009,
#  'Total_Biomass_Prod': 3956.617,
#  'Total_Energy_Consumption': 93942.216,
#  'Total_Renewable_Consumption': 7608.324,
#  'Total_Renewable_Production': 7624.932,
#  'WasteEnergy_Consumption': 451.687,
#  'Wind_Consumption': 721.129,
#  'Wood_Consumption': 1935.01,
#  'Wood_production': 1935.01,
#  'Year': 2009,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b81f')}
# ------------------------
# {'Biofuel_Production': 1867.88,
#  'Biofuel_consumption': 1821.23,
#  'Geo_Consumption': 207.979,
#  'Hydro_consumption': 2538.541,
#  'Solar_Consumption': 91.282,
#  'Total_Biomass_Consumption': 4505.882,
#  'Total_Biomass_Prod': 4552.532,
#  'Total_Energy_Consumption': 97513.239,
#  'Total_Renewable_Consumption': 8267.112,
#  'Total_Renewable_Production': 8313.762,
#  'WasteEnergy_Consumption': 467.912,
#  'Wind_Consumption': 923.427,
#  'Wood_Consumption': 2216.74,
#  'Wood_production': 2216.74,
#  'Year': 2010,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b820')}
# ------------------------
# {'Biofuel_Production': 2029.308,
#  'Biofuel_consumption': 1933.919,
#  'Geo_Consumption': 212.311,
#  'Hydro_consumption': 3102.852,
#  'Solar_Consumption': 112.429,
#  'Total_Biomass_Consumption': 4608.932,
#  'Total_Biomass_Prod': 4704.321,
#  'Total_Energy_Consumption': 96862.56,
#  'Total_Renewable_Consumption': 9204.16,
#  'Total_Renewable_Production': 9299.548,
#  'WasteEnergy_Consumption': 461.793,
#  'Wind_Consumption': 1167.636,
#  'Wood_Consumption': 2213.22,
#  'Wood_production': 2213.22,
#  'Year': 2011,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b821')}
# ------------------------
# {'Biofuel_Production': 1928.887,
#  'Biofuel_consumption': 1889.988,
#  'Geo_Consumption': 211.592,
#  'Hydro_consumption': 2628.702,
#  'Solar_Consumption': 158.961,
#  'Total_Biomass_Consumption': 4507.805,
#  'Total_Biomass_Prod': 4546.704,
#  'Total_Energy_Consumption': 94374.079,
#  'Total_Renewable_Consumption': 8847.119,
#  'Total_Renewable_Production': 8886.018,
#  'WasteEnergy_Consumption': 466.604,
#  'Wind_Consumption': 1340.059,
#  'Wood_Consumption': 2151.213,
#  'Wood_production': 2151.213,
#  'Year': 2012,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b822')}
# ------------------------
# {'Biofuel_Production': 1980.94,
#  'Biofuel_consumption': 2013.662,
#  'Geo_Consumption': 214.006,
#  'Hydro_consumption': 2562.382,
#  'Solar_Consumption': 224.524,
#  'Total_Biomass_Consumption': 4848.354,
#  'Total_Biomass_Prod': 4815.632,
#  'Total_Energy_Consumption': 97116.80099999999,
#  'Total_Renewable_Consumption': 9450.625,
#  'Total_Renewable_Production': 9417.903,
#  'WasteEnergy_Consumption': 496.436,
#  'Wind_Consumption': 1601.359,
#  'Wood_Consumption': 2338.256,
#  'Wood_production': 2338.256,
#  'Year': 2013,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b823')}
# ------------------------
# {'Biofuel_Production': 2103.411,
#  'Biofuel_consumption': 2077.254,
#  'Geo_Consumption': 214.49,
#  'Hydro_consumption': 2466.577,
#  'Solar_Consumption': 337.543,
#  'Total_Biomass_Consumption': 4994.208,
#  'Total_Biomass_Prod': 5020.366,
#  'Total_Energy_Consumption': 98276.21,
#  'Total_Renewable_Consumption': 9740.36,
#  'Total_Renewable_Production': 9766.517,
#  'WasteEnergy_Consumption': 515.877,
#  'Wind_Consumption': 1727.542,
#  'Wood_Consumption': 2401.078,
#  'Wood_production': 2401.078,
#  'Year': 2014,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b824')}
# ------------------------
# {'Biofuel_Production': 2161.44,
#  'Biofuel_consumption': 2153.219,
#  'Geo_Consumption': 211.836,
#  'Hydro_consumption': 2321.177,
#  'Solar_Consumption': 426.867,
#  'Total_Biomass_Consumption': 4983.358,
#  'Total_Biomass_Prod': 4991.579,
#  'Total_Energy_Consumption': 97375.22099999999,
#  'Total_Renewable_Consumption': 9720.544,
#  'Total_Renewable_Production': 9728.765,
#  'WasteEnergy_Consumption': 518.371,
#  'Wind_Consumption': 1777.306,
#  'Wood_Consumption': 2311.768,
#  'Wood_production': 2311.768,
#  'Year': 2015,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b825')}
# ------------------------
# {'Biofuel_Production': 2274.948,
#  'Biofuel_consumption': 2287.182,
#  'Geo_Consumption': 209.604,
#  'Hydro_consumption': 2472.442,
#  'Solar_Consumption': 570.368,
#  'Total_Biomass_Consumption': 5014.521,
#  'Total_Biomass_Prod': 5074.863,
#  'Total_Energy_Consumption': 97335.208,
#  'Total_Renewable_Consumption': 10362.53,
#  'Total_Renewable_Production': 10422.872,
#  'WasteEnergy_Consumption': 503.219,
#  'Wind_Consumption': 2095.595,
#  'Wood_Consumption': 2224.121,
#  'Wood_production': 2296.696,
#  'Year': 2016,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b826')}
# ------------------------
# {'Biofuel_Production': 2344.298,
#  'Biofuel_consumption': 2303.518,
#  'Geo_Consumption': 210.233,
#  'Hydro_consumption': 2766.967,
#  'Solar_Consumption': 777.084,
#  'Total_Biomass_Consumption': 4979.34,
#  'Total_Biomass_Prod': 5098.747,
#  'Total_Energy_Consumption': 97594.74299999999,
#  'Total_Renewable_Consumption': 11076.515,
#  'Total_Renewable_Production': 11195.923,
#  'WasteEnergy_Consumption': 495.26,
#  'Wind_Consumption': 2342.891,
#  'Wood_Consumption': 2180.563,
#  'Wood_production': 2259.189,
#  'Year': 2017,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b827')}
# ------------------------
# {'Biofuel_Production': 2396.573,
#  'Biofuel_consumption': 2283.247,
#  'Geo_Consumption': 208.865,
#  'Hydro_consumption': 2663.138,
#  'Solar_Consumption': 915.513,
#  'Total_Biomass_Consumption': 5031.1,
#  'Total_Biomass_Prod': 5238.484,
#  'Total_Energy_Consumption': 101161.852,
#  'Total_Renewable_Consumption': 11300.98,
#  'Total_Renewable_Production': 11508.364,
#  'WasteEnergy_Consumption': 487.347,
#  'Wind_Consumption': 2482.364,
#  'Wood_Consumption': 2260.506,
#  'Wood_production': 2354.564,
#  'Year': 2018,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b828')}
# ------------------------
# {'Biofuel_Production': 2327.517,
#  'Biofuel_consumption': 2254.725,
#  'Geo_Consumption': 201.269,
#  'Hydro_consumption': 2563.228,
#  'Solar_Consumption': 1018.013,
#  'Total_Biomass_Consumption': 4923.807,
#  'Total_Biomass_Prod': 5100.242,
#  'Total_Energy_Consumption': 100273.806,
#  'Total_Renewable_Consumption': 11332.162,
#  'Total_Renewable_Production': 11508.598,
#  'WasteEnergy_Consumption': 442.447,
#  'Wind_Consumption': 2625.846,
#  'Wood_Consumption': 2226.635,
#  'Wood_production': 2330.279,
#  'Year': 2019,
#  '_id': ObjectId('5fc6fe9bb7abff5a7656b829')}
# ------------------------

# %%
# save the population data frame into the mongo cloud
#Declare the collection
col_population=db['Populationdata']

pop_data=pop_df.to_dict('records')
col_population.insert_many(pop_data)

# %%
col_uspop = db["USPopulation"]
col_uspop.insert_many(us_pop.to_dict('records'))

# %%
for row in db.Populationdata.find():
    pprint(row)
    print("------------------------")
# Out:
# {'Population': 4780125,
#  'State': 'Alabama',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b50c')}
# ------------------------
# {'Population': 710249,
#  'State': 'Alaska',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b50d')}
# ------------------------
# {'Population': 6392288,
#  'State': 'Arizona',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b50e')}
# ------------------------
# {'Population': 2916031,
#  'State': 'Arkansas',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b50f')}
# ------------------------
# {'Population': 37254519,
#  'State': 'California',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b510')}
# ------------------------
# {'Population': 5029319,
#  'State': 'Colorado',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b511')}
# ------------------------
# {'Population': 3574147,
#  'State': 'Connecticut',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b512')}
# ------------------------
# {'Population': 897937,
#  'State': 'Delaware',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b513')}
# ------------------------
# {'Population': 601767,
#  'State': 'District of Columbia',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b514')}
# ------------------------
# {'Population': 18804564,
#  'State': 'Florida',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b515')}
# ------------------------
# {'Population': 9688729,
#  'State': 'Georgia',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b516')}
# ------------------------
# {'Population': 1360307,
#  'State': 'Hawaii',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b517')}
# ------------------------
# {'Population': 1567657,
#  'State': 'Idaho',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b518')}
# ------------------------
# {'Population': 12831572,
#  'State': 'Illinois',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b519')}
# ------------------------
# {'Population': 6484051,
#  'State': 'Indiana',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51a')}
# ------------------------
# {'Population': 3046871,
#  'State': 'Iowa',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51b')}
# ------------------------
# {'Population': 2853123,
#  'State': 'Kansas',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51c')}
# ------------------------
# {'Population': 4339333,
#  'State': 'Kentucky',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51d')}
# ------------------------
# {'Population': 4533487,
#  'State': 'Louisiana',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51e')}
# ------------------------
# {'Population': 1328358,
#  'State': 'Maine',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b51f')}
# ------------------------
# {'Population': 5773794,
#  'State': 'Maryland',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b520')}
# ------------------------
# {'Population': 6547785,
#  'State': 'Massachusetts',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b521')}
# ------------------------
# {'Population': 9884116,
#  'State': 'Michigan',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b522')}
# ------------------------
# {'Population': 5303927,
#  'State': 'Minnesota',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b523')}
# ------------------------
# {'Population': 2968130,
#  'State': 'Mississippi',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b524')}
# ------------------------
# {'Population': 5988950,
#  'State': 'Missouri',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b525')}
# ------------------------
# {'Population': 989407,
#  'State': 'Montana',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b526')}
# ------------------------
# {'Population': 1826305,
#  'State': 'Nebraska',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b527')}
# ------------------------
# {'Population': 2700677,
#  'State': 'Nevada',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b528')}
# ------------------------
# {'Population': 1316462,
#  'State': 'New Hampshire',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b529')}
# ------------------------
# {'Population': 8791978,
#  'State': 'New Jersey',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52a')}
# ------------------------
# {'Population': 2059199,
#  'State': 'New Mexico',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52b')}
# ------------------------
# {'Population': 19378144,
#  'State': 'New York',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52c')}
# ------------------------
# {'Population': 9535751,
#  'State': 'North Carolina',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52d')}
# ------------------------
# {'Population': 672576,
#  'State': 'North Dakota',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52e')}
# ------------------------
# {'Population': 11536751,
#  'State': 'Ohio',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b52f')}
# ------------------------
# {'Population': 3751582,
#  'State': 'Oklahoma',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b530')}
# ------------------------
# {'Population': 3831079,
#  'State': 'Oregon',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b531')}
# ------------------------
# {'Population': 12702868,
#  'State': 'Pennsylvania',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b532')}
# ------------------------
# {'Population': 1052964,
#  'State': 'Rhode Island',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b533')}
# ------------------------
# {'Population': 4625366,
#  'State': 'South Carolina',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b534')}
# ------------------------
# {'Population': 814198,
#  'State': 'South Dakota',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b535')}
# ------------------------
# {'Population': 6346276,
#  'State': 'Tennessee',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b536')}
# ------------------------
# {'Population': 25146091,
#  'State': 'Texas',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b537')}
# ------------------------
# {'Population': 2763891,
#  'State': 'Utah',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b538')}
# ------------------------
# {'Population': 625737,
#  'State': 'Vermont',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b539')}
# ------------------------
# {'Population': 8001049,
#  'State': 'Virginia',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53a')}
# ------------------------
# {'Population': 6724540,
#  'State': 'Washington',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53b')}
# ------------------------
# {'Population': 1853018,
#  'State': 'West Virginia',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53c')}
# ------------------------
# {'Population': 5687285,
#  'State': 'Wisconsin',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53d')}
# ------------------------
# {'Population': 563775,
#  'State': 'Wyoming',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53e')}
# ------------------------
# {'Population': 3726157,
#  'State': 'Puerto Rico',
#  'Year': 'EST2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b53f')}
# ------------------------
# {'Population': 4785437,
#  'State': 'Alabama',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b540')}
# ------------------------
# {'Population': 713910,
#  'State': 'Alaska',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b541')}
# ------------------------
# {'Population': 6407172,
#  'State': 'Arizona',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b542')}
# ------------------------
# {'Population': 2921964,
#  'State': 'Arkansas',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b543')}
# ------------------------
# {'Population': 37319502,
#  'State': 'California',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b544')}
# ------------------------
# {'Population': 5047349,
#  'State': 'Colorado',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b545')}
# ------------------------
# {'Population': 3579114,
#  'State': 'Connecticut',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b546')}
# ------------------------
# {'Population': 899593,
#  'State': 'Delaware',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b547')}
# ------------------------
# {'Population': 605226,
#  'State': 'District of Columbia',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b548')}
# ------------------------
# {'Population': 18845537,
#  'State': 'Florida',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b549')}
# ------------------------
# {'Population': 9711881,
#  'State': 'Georgia',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54a')}
# ------------------------
# {'Population': 1363963,
#  'State': 'Hawaii',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54b')}
# ------------------------
# {'Population': 1570746,
#  'State': 'Idaho',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54c')}
# ------------------------
# {'Population': 12840503,
#  'State': 'Illinois',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54d')}
# ------------------------
# {'Population': 6490432,
#  'State': 'Indiana',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54e')}
# ------------------------
# {'Population': 3050745,
#  'State': 'Iowa',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b54f')}
# ------------------------
# {'Population': 2858190,
#  'State': 'Kansas',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b550')}
# ------------------------
# {'Population': 4348181,
#  'State': 'Kentucky',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b551')}
# ------------------------
# {'Population': 4544532,
#  'State': 'Louisiana',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b552')}
# ------------------------
# {'Population': 1327629,
#  'State': 'Maine',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b553')}
# ------------------------
# {'Population': 5788645,
#  'State': 'Maryland',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b554')}
# ------------------------
# {'Population': 6566307,
#  'State': 'Massachusetts',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b555')}
# ------------------------
# {'Population': 9877510,
#  'State': 'Michigan',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b556')}
# ------------------------
# {'Population': 5310828,
#  'State': 'Minnesota',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b557')}
# ------------------------
# {'Population': 2970548,
#  'State': 'Mississippi',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b558')}
# ------------------------
# {'Population': 5995974,
#  'State': 'Missouri',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b559')}
# ------------------------
# {'Population': 990697,
#  'State': 'Montana',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55a')}
# ------------------------
# {'Population': 1829542,
#  'State': 'Nebraska',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55b')}
# ------------------------
# {'Population': 2702405,
#  'State': 'Nevada',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55c')}
# ------------------------
# {'Population': 1316762,
#  'State': 'New Hampshire',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55d')}
# ------------------------
# {'Population': 8799446,
#  'State': 'New Jersey',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55e')}
# ------------------------
# {'Population': 2064552,
#  'State': 'New Mexico',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b55f')}
# ------------------------
# {'Population': 19399878,
#  'State': 'New York',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b560')}
# ------------------------
# {'Population': 9574323,
#  'State': 'North Carolina',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b561')}
# ------------------------
# {'Population': 674715,
#  'State': 'North Dakota',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b562')}
# ------------------------
# {'Population': 11539336,
#  'State': 'Ohio',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b563')}
# ------------------------
# {'Population': 3759944,
#  'State': 'Oklahoma',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b564')}
# ------------------------
# {'Population': 3837491,
#  'State': 'Oregon',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b565')}
# ------------------------
# {'Population': 12711160,
#  'State': 'Pennsylvania',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b566')}
# ------------------------
# {'Population': 1053959,
#  'State': 'Rhode Island',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b567')}
# ------------------------
# {'Population': 4635649,
#  'State': 'South Carolina',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b568')}
# ------------------------
# {'Population': 816166,
#  'State': 'South Dakota',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b569')}
# ------------------------
# {'Population': 6355311,
#  'State': 'Tennessee',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56a')}
# ------------------------
# {'Population': 25241971,
#  'State': 'Texas',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56b')}
# ------------------------
# {'Population': 2775332,
#  'State': 'Utah',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56c')}
# ------------------------
# {'Population': 625879,
#  'State': 'Vermont',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56d')}
# ------------------------
# {'Population': 8023699,
#  'State': 'Virginia',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56e')}
# ------------------------
# {'Population': 6742830,
#  'State': 'Washington',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b56f')}
# ------------------------
# {'Population': 1854239,
#  'State': 'West Virginia',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b570')}
# ------------------------
# {'Population': 5690475,
#  'State': 'Wisconsin',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b571')}
# ------------------------
# {'Population': 564487,
#  'State': 'Wyoming',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b572')}
# ------------------------
# {'Population': 3721525,
#  'State': 'Puerto Rico',
#  'Year': '2010',
#  '_id': ObjectId('5fc6955bb7abff5a7656b573')}
# ------------------------
# {'Population': 4799069,
#  'State': 'Alabama',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b574')}
# ------------------------
# {'Population': 722128,
#  'State': 'Alaska',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b575')}
# ------------------------
# {'Population': 6472643,
#  'State': 'Arizona',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b576')}
# ------------------------
# {'Population': 2940667,
#  'State': 'Arkansas',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b577')}
# ------------------------
# {'Population': 37638369,
#  'State': 'California',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b578')}
# ------------------------
# {'Population': 5121108,
#  'State': 'Colorado',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b579')}
# ------------------------
# {'Population': 3588283,
#  'State': 'Connecticut',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57a')}
# ------------------------
# {'Population': 907381,
#  'State': 'Delaware',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57b')}
# ------------------------
# {'Population': 619800,
#  'State': 'District of Columbia',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57c')}
# ------------------------
# {'Population': 19053237,
#  'State': 'Florida',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57d')}
# ------------------------
# {'Population': 9802431,
#  'State': 'Georgia',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57e')}
# ------------------------
# {'Population': 1379329,
#  'State': 'Hawaii',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b57f')}
# ------------------------
# {'Population': 1583910,
#  'State': 'Idaho',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b580')}
# ------------------------
# {'Population': 12867454,
#  'State': 'Illinois',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b581')}
# ------------------------
# {'Population': 6516528,
#  'State': 'Indiana',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b582')}
# ------------------------
# {'Population': 3066336,
#  'State': 'Iowa',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b583')}
# ------------------------
# {'Population': 2869225,
#  'State': 'Kansas',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b584')}
# ------------------------
# {'Population': 4369821,
#  'State': 'Kentucky',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b585')}
# ------------------------
# {'Population': 4575625,
#  'State': 'Louisiana',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b586')}
# ------------------------
# {'Population': 1328284,
#  'State': 'Maine',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b587')}
# ------------------------
# {'Population': 5839419,
#  'State': 'Maryland',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b588')}
# ------------------------
# {'Population': 6613583,
#  'State': 'Massachusetts',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b589')}
# ------------------------
# {'Population': 9882412,
#  'State': 'Michigan',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58a')}
# ------------------------
# {'Population': 5346143,
#  'State': 'Minnesota',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58b')}
# ------------------------
# {'Population': 2978731,
#  'State': 'Mississippi',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58c')}
# ------------------------
# {'Population': 6010275,
#  'State': 'Missouri',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58d')}
# ------------------------
# {'Population': 997316,
#  'State': 'Montana',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58e')}
# ------------------------
# {'Population': 1840672,
#  'State': 'Nebraska',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b58f')}
# ------------------------
# {'Population': 2712730,
#  'State': 'Nevada',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b590')}
# ------------------------
# {'Population': 1320202,
#  'State': 'New Hampshire',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b591')}
# ------------------------
# {'Population': 8828117,
#  'State': 'New Jersey',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b592')}
# ------------------------
# {'Population': 2080450,
#  'State': 'New Mexico',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b593')}
# ------------------------
# {'Population': 19499241,
#  'State': 'New York',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b594')}
# ------------------------
# {'Population': 9657592,
#  'State': 'North Carolina',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b595')}
# ------------------------
# {'Population': 685225,
#  'State': 'North Dakota',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b596')}
# ------------------------
# {'Population': 11544663,
#  'State': 'Ohio',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b597')}
# ------------------------
# {'Population': 3788379,
#  'State': 'Oklahoma',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b598')}
# ------------------------
# {'Population': 3872036,
#  'State': 'Oregon',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b599')}
# ------------------------
# {'Population': 12745815,
#  'State': 'Pennsylvania',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59a')}
# ------------------------
# {'Population': 1053649,
#  'State': 'Rhode Island',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59b')}
# ------------------------
# {'Population': 4671994,
#  'State': 'South Carolina',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59c')}
# ------------------------
# {'Population': 823579,
#  'State': 'South Dakota',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59d')}
# ------------------------
# {'Population': 6399291,
#  'State': 'Tennessee',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59e')}
# ------------------------
# {'Population': 25645629,
#  'State': 'Texas',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b59f')}
# ------------------------
# {'Population': 2814384,
#  'State': 'Utah',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a0')}
# ------------------------
# {'Population': 627049,
#  'State': 'Vermont',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a1')}
# ------------------------
# {'Population': 8101155,
#  'State': 'Virginia',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a2')}
# ------------------------
# {'Population': 6826627,
#  'State': 'Washington',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a3')}
# ------------------------
# {'Population': 1856301,
#  'State': 'West Virginia',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a4')}
# ------------------------
# {'Population': 5705288,
#  'State': 'Wisconsin',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a5')}
# ------------------------
# {'Population': 567299,
#  'State': 'Wyoming',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a6')}
# ------------------------
# {'Population': 3678732,
#  'State': 'Puerto Rico',
#  'Year': '2011',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a7')}
# ------------------------
# {'Population': 4815588,
#  'State': 'Alabama',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a8')}
# ------------------------
# {'Population': 730443,
#  'State': 'Alaska',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5a9')}
# ------------------------
# {'Population': 6554978,
#  'State': 'Arizona',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5aa')}
# ------------------------
# {'Population': 2952164,
#  'State': 'Arkansas',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ab')}
# ------------------------
# {'Population': 37948800,
#  'State': 'California',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ac')}
# ------------------------
# {'Population': 5192647,
#  'State': 'Colorado',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ad')}
# ------------------------
# {'Population': 3594547,
#  'State': 'Connecticut',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ae')}
# ------------------------
# {'Population': 915179,
#  'State': 'Delaware',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5af')}
# ------------------------
# {'Population': 634924,
#  'State': 'District of Columbia',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b0')}
# ------------------------
# {'Population': 19297822,
#  'State': 'Florida',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b1')}
# ------------------------
# {'Population': 9901430,
#  'State': 'Georgia',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b2')}
# ------------------------
# {'Population': 1394804,
#  'State': 'Hawaii',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b3')}
# ------------------------
# {'Population': 1595324,
#  'State': 'Idaho',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b4')}
# ------------------------
# {'Population': 12882510,
#  'State': 'Illinois',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b5')}
# ------------------------
# {'Population': 6537703,
#  'State': 'Indiana',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b6')}
# ------------------------
# {'Population': 3076190,
#  'State': 'Iowa',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b7')}
# ------------------------
# {'Population': 2885257,
#  'State': 'Kansas',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b8')}
# ------------------------
# {'Population': 4386346,
#  'State': 'Kentucky',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5b9')}
# ------------------------
# {'Population': 4600972,
#  'State': 'Louisiana',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ba')}
# ------------------------
# {'Population': 1327729,
#  'State': 'Maine',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5bb')}
# ------------------------
# {'Population': 5886992,
#  'State': 'Maryland',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5bc')}
# ------------------------
# {'Population': 6663005,
#  'State': 'Massachusetts',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5bd')}
# ------------------------
# {'Population': 9897145,
#  'State': 'Michigan',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5be')}
# ------------------------
# {'Population': 5376643,
#  'State': 'Minnesota',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5bf')}
# ------------------------
# {'Population': 2983816,
#  'State': 'Mississippi',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c0')}
# ------------------------
# {'Population': 6024367,
#  'State': 'Missouri',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c1')}
# ------------------------
# {'Population': 1003783,
#  'State': 'Montana',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c2')}
# ------------------------
# {'Population': 1853303,
#  'State': 'Nebraska',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c3')}
# ------------------------
# {'Population': 2743996,
#  'State': 'Nevada',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c4')}
# ------------------------
# {'Population': 1324232,
#  'State': 'New Hampshire',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c5')}
# ------------------------
# {'Population': 8844942,
#  'State': 'New Jersey',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c6')}
# ------------------------
# {'Population': 2087309,
#  'State': 'New Mexico',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c7')}
# ------------------------
# {'Population': 19572932,
#  'State': 'New York',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c8')}
# ------------------------
# {'Population': 9749476,
#  'State': 'North Carolina',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5c9')}
# ------------------------
# {'Population': 701176,
#  'State': 'North Dakota',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ca')}
# ------------------------
# {'Population': 11548923,
#  'State': 'Ohio',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5cb')}
# ------------------------
# {'Population': 3818814,
#  'State': 'Oklahoma',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5cc')}
# ------------------------
# {'Population': 3899001,
#  'State': 'Oregon',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5cd')}
# ------------------------
# {'Population': 12767118,
#  'State': 'Pennsylvania',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ce')}
# ------------------------
# {'Population': 1054621,
#  'State': 'Rhode Island',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5cf')}
# ------------------------
# {'Population': 4717354,
#  'State': 'South Carolina',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d0')}
# ------------------------
# {'Population': 833566,
#  'State': 'South Dakota',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d1')}
# ------------------------
# {'Population': 6453898,
#  'State': 'Tennessee',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d2')}
# ------------------------
# {'Population': 26084481,
#  'State': 'Texas',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d3')}
# ------------------------
# {'Population': 2853375,
#  'State': 'Utah',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d4')}
# ------------------------
# {'Population': 626090,
#  'State': 'Vermont',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d5')}
# ------------------------
# {'Population': 8185080,
#  'State': 'Virginia',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d6')}
# ------------------------
# {'Population': 6897058,
#  'State': 'Washington',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d7')}
# ------------------------
# {'Population': 1856872,
#  'State': 'West Virginia',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d8')}
# ------------------------
# {'Population': 5719960,
#  'State': 'Wisconsin',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5d9')}
# ------------------------
# {'Population': 576305,
#  'State': 'Wyoming',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5da')}
# ------------------------
# {'Population': 3634488,
#  'State': 'Puerto Rico',
#  'Year': '2012',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5db')}
# ------------------------
# {'Population': 4830081,
#  'State': 'Alabama',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5dc')}
# ------------------------
# {'Population': 737068,
#  'State': 'Alaska',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5dd')}
# ------------------------
# {'Population': 6632764,
#  'State': 'Arizona',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5de')}
# ------------------------
# {'Population': 2959400,
#  'State': 'Arkansas',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5df')}
# ------------------------
# {'Population': 38260787,
#  'State': 'California',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e0')}
# ------------------------
# {'Population': 5269035,
#  'State': 'Colorado',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e1')}
# ------------------------
# {'Population': 3594841,
#  'State': 'Connecticut',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e2')}
# ------------------------
# {'Population': 923576,
#  'State': 'Delaware',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e3')}
# ------------------------
# {'Population': 650581,
#  'State': 'District of Columbia',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e4')}
# ------------------------
# {'Population': 19545621,
#  'State': 'Florida',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e5')}
# ------------------------
# {'Population': 9972479,
#  'State': 'Georgia',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e6')}
# ------------------------
# {'Population': 1408243,
#  'State': 'Hawaii',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e7')}
# ------------------------
# {'Population': 1611206,
#  'State': 'Idaho',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e8')}
# ------------------------
# {'Population': 12895129,
#  'State': 'Illinois',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5e9')}
# ------------------------
# {'Population': 6568713,
#  'State': 'Indiana',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ea')}
# ------------------------
# {'Population': 3092997,
#  'State': 'Iowa',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5eb')}
# ------------------------
# {'Population': 2893212,
#  'State': 'Kansas',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ec')}
# ------------------------
# {'Population': 4404659,
#  'State': 'Kentucky',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ed')}
# ------------------------
# {'Population': 4624527,
#  'State': 'Louisiana',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ee')}
# ------------------------
# {'Population': 1328009,
#  'State': 'Maine',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ef')}
# ------------------------
# {'Population': 5923188,
#  'State': 'Maryland',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f0')}
# ------------------------
# {'Population': 6713315,
#  'State': 'Massachusetts',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f1')}
# ------------------------
# {'Population': 9913065,
#  'State': 'Michigan',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f2')}
# ------------------------
# {'Population': 5413479,
#  'State': 'Minnesota',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f3')}
# ------------------------
# {'Population': 2988711,
#  'State': 'Mississippi',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f4')}
# ------------------------
# {'Population': 6040715,
#  'State': 'Missouri',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f5')}
# ------------------------
# {'Population': 1013569,
#  'State': 'Montana',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f6')}
# ------------------------
# {'Population': 1865279,
#  'State': 'Nebraska',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f7')}
# ------------------------
# {'Population': 2775970,
#  'State': 'Nevada',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f8')}
# ------------------------
# {'Population': 1326622,
#  'State': 'New Hampshire',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5f9')}
# ------------------------
# {'Population': 8856972,
#  'State': 'New Jersey',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5fa')}
# ------------------------
# {'Population': 2092273,
#  'State': 'New Mexico',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5fb')}
# ------------------------
# {'Population': 19624447,
#  'State': 'New York',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5fc')}
# ------------------------
# {'Population': 9843336,
#  'State': 'North Carolina',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5fd')}
# ------------------------
# {'Population': 722036,
#  'State': 'North Dakota',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5fe')}
# ------------------------
# {'Population': 11576684,
#  'State': 'Ohio',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b5ff')}
# ------------------------
# {'Population': 3853214,
#  'State': 'Oklahoma',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b600')}
# ------------------------
# {'Population': 3922468,
#  'State': 'Oregon',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b601')}
# ------------------------
# {'Population': 12776309,
#  'State': 'Pennsylvania',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b602')}
# ------------------------
# {'Population': 1055081,
#  'State': 'Rhode Island',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b603')}
# ------------------------
# {'Population': 4764080,
#  'State': 'South Carolina',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b604')}
# ------------------------
# {'Population': 842316,
#  'State': 'South Dakota',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b605')}
# ------------------------
# {'Population': 6494340,
#  'State': 'Tennessee',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b606')}
# ------------------------
# {'Population': 26480266,
#  'State': 'Texas',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b607')}
# ------------------------
# {'Population': 2897640,
#  'State': 'Utah',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b608')}
# ------------------------
# {'Population': 626210,
#  'State': 'Vermont',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b609')}
# ------------------------
# {'Population': 8252427,
#  'State': 'Virginia',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60a')}
# ------------------------
# {'Population': 6963985,
#  'State': 'Washington',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60b')}
# ------------------------
# {'Population': 1853914,
#  'State': 'West Virginia',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60c')}
# ------------------------
# {'Population': 5736754,
#  'State': 'Wisconsin',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60d')}
# ------------------------
# {'Population': 582122,
#  'State': 'Wyoming',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60e')}
# ------------------------
# {'Population': 3593077,
#  'State': 'Puerto Rico',
#  'Year': '2013',
#  '_id': ObjectId('5fc6955bb7abff5a7656b60f')}
# ------------------------
# {'Population': 4841799,
#  'State': 'Alabama',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b610')}
# ------------------------
# {'Population': 736283,
#  'State': 'Alaska',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b611')}
# ------------------------
# {'Population': 6730413,
#  'State': 'Arizona',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b612')}
# ------------------------
# {'Population': 2967392,
#  'State': 'Arkansas',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b613')}
# ------------------------
# {'Population': 38596972,
#  'State': 'California',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b614')}
# ------------------------
# {'Population': 5350101,
#  'State': 'Colorado',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b615')}
# ------------------------
# {'Population': 3594524,
#  'State': 'Connecticut',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b616')}
# ------------------------
# {'Population': 932487,
#  'State': 'Delaware',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b617')}
# ------------------------
# {'Population': 662328,
#  'State': 'District of Columbia',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b618')}
# ------------------------
# {'Population': 19845911,
#  'State': 'Florida',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b619')}
# ------------------------
# {'Population': 10067278,
#  'State': 'Georgia',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61a')}
# ------------------------
# {'Population': 1414538,
#  'State': 'Hawaii',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61b')}
# ------------------------
# {'Population': 1631112,
#  'State': 'Idaho',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61c')}
# ------------------------
# {'Population': 12884493,
#  'State': 'Illinois',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61d')}
# ------------------------
# {'Population': 6593644,
#  'State': 'Indiana',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61e')}
# ------------------------
# {'Population': 3109350,
#  'State': 'Iowa',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b61f')}
# ------------------------
# {'Population': 2900475,
#  'State': 'Kansas',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b620')}
# ------------------------
# {'Population': 4414349,
#  'State': 'Kentucky',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b621')}
# ------------------------
# {'Population': 4644013,
#  'State': 'Louisiana',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b622')}
# ------------------------
# {'Population': 1330513,
#  'State': 'Maine',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b623')}
# ------------------------
# {'Population': 5957283,
#  'State': 'Maryland',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b624')}
# ------------------------
# {'Population': 6762596,
#  'State': 'Massachusetts',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b625')}
# ------------------------
# {'Population': 9929848,
#  'State': 'Michigan',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b626')}
# ------------------------
# {'Population': 5451079,
#  'State': 'Minnesota',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b627')}
# ------------------------
# {'Population': 2990468,
#  'State': 'Mississippi',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b628')}
# ------------------------
# {'Population': 6056202,
#  'State': 'Missouri',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b629')}
# ------------------------
# {'Population': 1021869,
#  'State': 'Montana',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62a')}
# ------------------------
# {'Population': 1879321,
#  'State': 'Nebraska',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62b')}
# ------------------------
# {'Population': 2817628,
#  'State': 'Nevada',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62c')}
# ------------------------
# {'Population': 1333341,
#  'State': 'New Hampshire',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62d')}
# ------------------------
# {'Population': 8864525,
#  'State': 'New Jersey',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62e')}
# ------------------------
# {'Population': 2089568,
#  'State': 'New Mexico',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b62f')}
# ------------------------
# {'Population': 19651049,
#  'State': 'New York',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b630')}
# ------------------------
# {'Population': 9932887,
#  'State': 'North Carolina',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b631')}
# ------------------------
# {'Population': 737401,
#  'State': 'North Dakota',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b632')}
# ------------------------
# {'Population': 11602700,
#  'State': 'Ohio',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b633')}
# ------------------------
# {'Population': 3878187,
#  'State': 'Oklahoma',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b634')}
# ------------------------
# {'Population': 3963244,
#  'State': 'Oregon',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b635')}
# ------------------------
# {'Population': 12788313,
#  'State': 'Pennsylvania',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b636')}
# ------------------------
# {'Population': 1055936,
#  'State': 'Rhode Island',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b637')}
# ------------------------
# {'Population': 4823617,
#  'State': 'South Carolina',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b638')}
# ------------------------
# {'Population': 849129,
#  'State': 'South Dakota',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b639')}
# ------------------------
# {'Population': 6541223,
#  'State': 'Tennessee',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63a')}
# ------------------------
# {'Population': 26964333,
#  'State': 'Texas',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63b')}
# ------------------------
# {'Population': 2936879,
#  'State': 'Utah',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63c')}
# ------------------------
# {'Population': 625214,
#  'State': 'Vermont',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63d')}
# ------------------------
# {'Population': 8310993,
#  'State': 'Virginia',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63e')}
# ------------------------
# {'Population': 7054655,
#  'State': 'Washington',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b63f')}
# ------------------------
# {'Population': 1849489,
#  'State': 'West Virginia',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b640')}
# ------------------------
# {'Population': 5751525,
#  'State': 'Wisconsin',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b641')}
# ------------------------
# {'Population': 582531,
#  'State': 'Wyoming',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b642')}
# ------------------------
# {'Population': 3534874,
#  'State': 'Puerto Rico',
#  'Year': '2014',
#  '_id': ObjectId('5fc6955bb7abff5a7656b643')}
# ------------------------
# {'Population': 4852347,
#  'State': 'Alabama',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b644')}
# ------------------------
# {'Population': 737498,
#  'State': 'Alaska',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b645')}
# ------------------------
# {'Population': 6829676,
#  'State': 'Arizona',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b646')}
# ------------------------
# {'Population': 2978048,
#  'State': 'Arkansas',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b647')}
# ------------------------
# {'Population': 38918045,
#  'State': 'California',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b648')}
# ------------------------
# {'Population': 5450623,
#  'State': 'Colorado',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b649')}
# ------------------------
# {'Population': 3587122,
#  'State': 'Connecticut',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64a')}
# ------------------------
# {'Population': 941252,
#  'State': 'Delaware',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64b')}
# ------------------------
# {'Population': 675400,
#  'State': 'District of Columbia',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64c')}
# ------------------------
# {'Population': 20209042,
#  'State': 'Florida',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64d')}
# ------------------------
# {'Population': 10178447,
#  'State': 'Georgia',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64e')}
# ------------------------
# {'Population': 1422052,
#  'State': 'Hawaii',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b64f')}
# ------------------------
# {'Population': 1651059,
#  'State': 'Idaho',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b650')}
# ------------------------
# {'Population': 12858913,
#  'State': 'Illinois',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b651')}
# ------------------------
# {'Population': 6608422,
#  'State': 'Indiana',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b652')}
# ------------------------
# {'Population': 3120960,
#  'State': 'Iowa',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b653')}
# ------------------------
# {'Population': 2909011,
#  'State': 'Kansas',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b654')}
# ------------------------
# {'Population': 4425976,
#  'State': 'Kentucky',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b655')}
# ------------------------
# {'Population': 4664628,
#  'State': 'Louisiana',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b656')}
# ------------------------
# {'Population': 1328262,
#  'State': 'Maine',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b657')}
# ------------------------
# {'Population': 5985562,
#  'State': 'Maryland',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b658')}
# ------------------------
# {'Population': 6794228,
#  'State': 'Massachusetts',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b659')}
# ------------------------
# {'Population': 9931715,
#  'State': 'Michigan',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65a')}
# ------------------------
# {'Population': 5482032,
#  'State': 'Minnesota',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65b')}
# ------------------------
# {'Population': 2988471,
#  'State': 'Mississippi',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65c')}
# ------------------------
# {'Population': 6071732,
#  'State': 'Missouri',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65d')}
# ------------------------
# {'Population': 1030475,
#  'State': 'Montana',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65e')}
# ------------------------
# {'Population': 1891277,
#  'State': 'Nebraska',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b65f')}
# ------------------------
# {'Population': 2866939,
#  'State': 'Nevada',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b660')}
# ------------------------
# {'Population': 1336350,
#  'State': 'New Hampshire',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b661')}
# ------------------------
# {'Population': 8867949,
#  'State': 'New Jersey',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b662')}
# ------------------------
# {'Population': 2089291,
#  'State': 'New Mexico',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b663')}
# ------------------------
# {'Population': 19654666,
#  'State': 'New York',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b664')}
# ------------------------
# {'Population': 10031646,
#  'State': 'North Carolina',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b665')}
# ------------------------
# {'Population': 754066,
#  'State': 'North Dakota',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b666')}
# ------------------------
# {'Population': 11617527,
#  'State': 'Ohio',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b667')}
# ------------------------
# {'Population': 3909500,
#  'State': 'Oklahoma',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b668')}
# ------------------------
# {'Population': 4015792,
#  'State': 'Oregon',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b669')}
# ------------------------
# {'Population': 12784826,
#  'State': 'Pennsylvania',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b66a')}
# ------------------------
# {'Population': 1056065,
#  'State': 'Rhode Island',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b66b')}
# ------------------------
# {'Population': 4891938,
#  'State': 'South Carolina',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b66c')}
# ------------------------
# {'Population': 853988,
#  'State': 'South Dakota',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b66d')}
# ------------------------
# {'Population': 6591170,
#  'State': 'Tennessee',
#  'Year': '2015',
#  '_id': ObjectId('5fc6955bb7abff5a7656b66e')}
# ------------------------
# ...
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d1')}
# ------------------------
# {'Population': 12787641,
#  'State': 'Pennsylvania',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d2')}
# ------------------------
# {'Population': 1055673,
#  'State': 'Rhode Island',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d3')}
# ------------------------
# {'Population': 5021268,
#  'State': 'South Carolina',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d4')}
# ------------------------
# {'Population': 872868,
#  'State': 'South Dakota',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d5')}
# ------------------------
# {'Population': 6708799,
#  'State': 'Tennessee',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d6')}
# ------------------------
# {'Population': 28295273,
#  'State': 'Texas',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d7')}
# ------------------------
# {'Population': 3101042,
#  'State': 'Utah',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d8')}
# ------------------------
# {'Population': 624344,
#  'State': 'Vermont',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6d9')}
# ------------------------
# {'Population': 8463587,
#  'State': 'Virginia',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6da')}
# ------------------------
# {'Population': 7423362,
#  'State': 'Washington',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6db')}
# ------------------------
# {'Population': 1817004,
#  'State': 'West Virginia',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6dc')}
# ------------------------
# {'Population': 5790186,
#  'State': 'Wisconsin',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6dd')}
# ------------------------
# {'Population': 578931,
#  'State': 'Wyoming',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6de')}
# ------------------------
# {'Population': 3325286,
#  'State': 'Puerto Rico',
#  'Year': '2017',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6df')}
# ------------------------
# {'Population': 4887681,
#  'State': 'Alabama',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e0')}
# ------------------------
# {'Population': 735139,
#  'State': 'Alaska',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e1')}
# ------------------------
# {'Population': 7158024,
#  'State': 'Arizona',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e2')}
# ------------------------
# {'Population': 3009733,
#  'State': 'Arkansas',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e3')}
# ------------------------
# {'Population': 39461588,
#  'State': 'California',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e4')}
# ------------------------
# {'Population': 5691287,
#  'State': 'Colorado',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e5')}
# ------------------------
# {'Population': 3571520,
#  'State': 'Connecticut',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e6')}
# ------------------------
# {'Population': 965479,
#  'State': 'Delaware',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e7')}
# ------------------------
# {'Population': 701547,
#  'State': 'District of Columbia',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e8')}
# ------------------------
# {'Population': 21244317,
#  'State': 'Florida',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6e9')}
# ------------------------
# {'Population': 10511131,
#  'State': 'Georgia',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ea')}
# ------------------------
# {'Population': 1420593,
#  'State': 'Hawaii',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6eb')}
# ------------------------
# {'Population': 1750536,
#  'State': 'Idaho',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ec')}
# ------------------------
# {'Population': 12723071,
#  'State': 'Illinois',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ed')}
# ------------------------
# {'Population': 6695497,
#  'State': 'Indiana',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ee')}
# ------------------------
# {'Population': 3148618,
#  'State': 'Iowa',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ef')}
# ------------------------
# {'Population': 2911359,
#  'State': 'Kansas',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f0')}
# ------------------------
# {'Population': 4461153,
#  'State': 'Kentucky',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f1')}
# ------------------------
# {'Population': 4659690,
#  'State': 'Louisiana',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f2')}
# ------------------------
# {'Population': 1339057,
#  'State': 'Maine',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f3')}
# ------------------------
# {'Population': 6035802,
#  'State': 'Maryland',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f4')}
# ------------------------
# {'Population': 6882635,
#  'State': 'Massachusetts',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f5')}
# ------------------------
# {'Population': 9984072,
#  'State': 'Michigan',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f6')}
# ------------------------
# {'Population': 5606249,
#  'State': 'Minnesota',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f7')}
# ------------------------
# {'Population': 2981020,
#  'State': 'Mississippi',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f8')}
# ------------------------
# {'Population': 6121623,
#  'State': 'Missouri',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6f9')}
# ------------------------
# {'Population': 1060665,
#  'State': 'Montana',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6fa')}
# ------------------------
# {'Population': 1925614,
#  'State': 'Nebraska',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6fb')}
# ------------------------
# {'Population': 3027341,
#  'State': 'Nevada',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6fc')}
# ------------------------
# {'Population': 1353465,
#  'State': 'New Hampshire',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6fd')}
# ------------------------
# {'Population': 8886025,
#  'State': 'New Jersey',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6fe')}
# ------------------------
# {'Population': 2092741,
#  'State': 'New Mexico',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b6ff')}
# ------------------------
# {'Population': 19530351,
#  'State': 'New York',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b700')}
# ------------------------
# {'Population': 10381615,
#  'State': 'North Carolina',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b701')}
# ------------------------
# {'Population': 758080,
#  'State': 'North Dakota',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b702')}
# ------------------------
# {'Population': 11676341,
#  'State': 'Ohio',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b703')}
# ------------------------
# {'Population': 3940235,
#  'State': 'Oklahoma',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b704')}
# ------------------------
# {'Population': 4181886,
#  'State': 'Oregon',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b705')}
# ------------------------
# {'Population': 12800922,
#  'State': 'Pennsylvania',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b706')}
# ------------------------
# {'Population': 1058287,
#  'State': 'Rhode Island',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b707')}
# ------------------------
# {'Population': 5084156,
#  'State': 'South Carolina',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b708')}
# ------------------------
# {'Population': 878698,
#  'State': 'South Dakota',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b709')}
# ------------------------
# {'Population': 6771631,
#  'State': 'Tennessee',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70a')}
# ------------------------
# {'Population': 28628666,
#  'State': 'Texas',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70b')}
# ------------------------
# {'Population': 3153550,
#  'State': 'Utah',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70c')}
# ------------------------
# {'Population': 624358,
#  'State': 'Vermont',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70d')}
# ------------------------
# {'Population': 8501286,
#  'State': 'Virginia',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70e')}
# ------------------------
# {'Population': 7523869,
#  'State': 'Washington',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b70f')}
# ------------------------
# {'Population': 1804291,
#  'State': 'West Virginia',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b710')}
# ------------------------
# {'Population': 5807406,
#  'State': 'Wisconsin',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b711')}
# ------------------------
# {'Population': 577601,
#  'State': 'Wyoming',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b712')}
# ------------------------
# {'Population': 3193354,
#  'State': 'Puerto Rico',
#  'Year': '2018',
#  '_id': ObjectId('5fc6955bb7abff5a7656b713')}
# ------------------------
# {'Population': 4903185,
#  'State': 'Alabama',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b714')}
# ------------------------
# {'Population': 731545,
#  'State': 'Alaska',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b715')}
# ------------------------
# {'Population': 7278717,
#  'State': 'Arizona',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b716')}
# ------------------------
# {'Population': 3017804,
#  'State': 'Arkansas',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b717')}
# ------------------------
# {'Population': 39512223,
#  'State': 'California',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b718')}
# ------------------------
# {'Population': 5758736,
#  'State': 'Colorado',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b719')}
# ------------------------
# {'Population': 3565287,
#  'State': 'Connecticut',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71a')}
# ------------------------
# {'Population': 973764,
#  'State': 'Delaware',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71b')}
# ------------------------
# {'Population': 705749,
#  'State': 'District of Columbia',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71c')}
# ------------------------
# {'Population': 21477737,
#  'State': 'Florida',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71d')}
# ------------------------
# {'Population': 10617423,
#  'State': 'Georgia',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71e')}
# ------------------------
# {'Population': 1415872,
#  'State': 'Hawaii',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b71f')}
# ------------------------
# {'Population': 1787065,
#  'State': 'Idaho',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b720')}
# ------------------------
# {'Population': 12671821,
#  'State': 'Illinois',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b721')}
# ------------------------
# {'Population': 6732219,
#  'State': 'Indiana',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b722')}
# ------------------------
# {'Population': 3155070,
#  'State': 'Iowa',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b723')}
# ------------------------
# {'Population': 2913314,
#  'State': 'Kansas',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b724')}
# ------------------------
# {'Population': 4467673,
#  'State': 'Kentucky',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b725')}
# ------------------------
# {'Population': 4648794,
#  'State': 'Louisiana',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b726')}
# ------------------------
# {'Population': 1344212,
#  'State': 'Maine',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b727')}
# ------------------------
# {'Population': 6045680,
#  'State': 'Maryland',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b728')}
# ------------------------
# {'Population': 6892503,
#  'State': 'Massachusetts',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b729')}
# ------------------------
# {'Population': 9986857,
#  'State': 'Michigan',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72a')}
# ------------------------
# {'Population': 5639632,
#  'State': 'Minnesota',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72b')}
# ------------------------
# {'Population': 2976149,
#  'State': 'Mississippi',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72c')}
# ------------------------
# {'Population': 6137428,
#  'State': 'Missouri',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72d')}
# ------------------------
# {'Population': 1068778,
#  'State': 'Montana',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72e')}
# ------------------------
# {'Population': 1934408,
#  'State': 'Nebraska',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b72f')}
# ------------------------
# {'Population': 3080156,
#  'State': 'Nevada',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b730')}
# ------------------------
# {'Population': 1359711,
#  'State': 'New Hampshire',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b731')}
# ------------------------
# {'Population': 8882190,
#  'State': 'New Jersey',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b732')}
# ------------------------
# {'Population': 2096829,
#  'State': 'New Mexico',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b733')}
# ------------------------
# {'Population': 19453561,
#  'State': 'New York',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b734')}
# ------------------------
# {'Population': 10488084,
#  'State': 'North Carolina',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b735')}
# ------------------------
# {'Population': 762062,
#  'State': 'North Dakota',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b736')}
# ------------------------
# {'Population': 11689100,
#  'State': 'Ohio',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b737')}
# ------------------------
# {'Population': 3956971,
#  'State': 'Oklahoma',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b738')}
# ------------------------
# {'Population': 4217737,
#  'State': 'Oregon',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b739')}
# ------------------------
# {'Population': 12801989,
#  'State': 'Pennsylvania',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73a')}
# ------------------------
# {'Population': 1059361,
#  'State': 'Rhode Island',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73b')}
# ------------------------
# {'Population': 5148714,
#  'State': 'South Carolina',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73c')}
# ------------------------
# {'Population': 884659,
#  'State': 'South Dakota',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73d')}
# ------------------------
# {'Population': 6829174,
#  'State': 'Tennessee',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73e')}
# ------------------------
# {'Population': 28995881,
#  'State': 'Texas',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b73f')}
# ------------------------
# {'Population': 3205958,
#  'State': 'Utah',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b740')}
# ------------------------
# {'Population': 623989,
#  'State': 'Vermont',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b741')}
# ------------------------
# {'Population': 8535519,
#  'State': 'Virginia',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b742')}
# ------------------------
# {'Population': 7614893,
#  'State': 'Washington',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b743')}
# ------------------------
# {'Population': 1792147,
#  'State': 'West Virginia',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b744')}
# ------------------------
# {'Population': 5822434,
#  'State': 'Wisconsin',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b745')}
# ------------------------
# {'Population': 578759,
#  'State': 'Wyoming',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b746')}
# ------------------------
# {'Population': 3193694,
#  'State': 'Puerto Rico',
#  'Year': '2019',
#  '_id': ObjectId('5fc6955bb7abff5a7656b747')}
# ------------------------
